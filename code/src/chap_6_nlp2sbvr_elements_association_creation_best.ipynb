# %% [markdown]
# <a href="https://colab.research.google.com/github/asantos2000/master-degree-santos-anderson/blob/main/code/src/chap_6_nlp2sbvr_elements_association_creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # nlp2sbvr - elements association and creation
#
# Chapter 6. Ferramentas de suporte
# - Section 6.2 Implementação dos principais componentes
#   - Section 6.2.4 nlp2sbvr
#     - Section Algoritmo "elements association and creation"
#     - Section Algoritmo "define vocabular namespace"
#     - Section Algoritmo "similarity search"
#
# > Use this version if the best scored elements will be inserted into KG, for the insertion of the last checkpoint use the "chap_6_nlp2sbvr_elements_association_creation.ipynb" instead. DO NOT USE BOTH.

# %% [markdown]
# ## Google colab

# %%
# %load_ext autoreload
# %autoreload 2

import sys

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
  from google.colab import drive
  drive.mount('/content/drive')
  # !rm -rf cfr2sbvr configuration checkpoint
  # !git clone https://github.com/asantos2000/master-degree-santos-anderson.git cfr2sbvr
  # %pip install -r cfr2sbvr/code/requirements.txt
  # !cp -r cfr2sbvr/code/src/configuration .
  # !cp -r cfr2sbvr/code/src/checkpoint .
  # !cp -r cfr2sbvr/code/config.colab.yaml config.yaml
  DEFAULT_CONFIG_FILE="config.yaml"
else:
  DEFAULT_CONFIG_FILE="../config.yaml"

# %% [markdown]
# ## Imports

# %%
# Standard library imports
import re
from decimal import Decimal
from datetime import datetime
import os

# Third-party libraries
from pydantic import BaseModel
from typing import List, Dict, Optional, Any, Tuple
import spacy
from slugify import slugify

# Franz AllegroGraph (AG) imports
from franz.openrdf.connect import ag_connect
from franz.openrdf.repository.repository import RepositoryConnection
from franz.openrdf.query.query import QueryLanguage

# Database
import duckdb

# Local application/library-specific imports
import configuration.main as configuration
import logging_setup.main as logging_setup

DEV_MODE = True

if DEV_MODE:
    # Development mode
    import importlib

    importlib.reload(configuration)
    importlib.reload(logging_setup)

# %% [markdown]
# ## Settings
#
# Default settings, check them before run the notebook.

# %% [markdown]
# ### Get configuration

# %%
# load config
config = configuration.load_config(DEFAULT_CONFIG_FILE)

# %% [markdown]
# ### Logging configuration

# %%
logger = logging_setup.setting_logging(config["DEFAULT_LOG_DIR"], config["LOG_LEVEL"])
# Out:
# 2025-01-30 19:08:47 - INFO - Logging is set up with daily rotation.

# %% [markdown]
# ## General functions and data structures

# %% [markdown]
# ### Database

# %%
def load_data(conn, table, checkpoints, doc_ids, statement_sources, process_selected):
    where_clause = ""
    if checkpoints:
        checkpoints_string = ", ".join(f"'{item}'" for item in checkpoints)
        where_clause += f" AND checkpoint in ({checkpoints_string})"

    if doc_ids:
        doc_ids_string = ", ".join(f"'{item}'" for item in doc_ids)
        where_clause += f" AND doc_id in ({doc_ids_string})"

    if statement_sources:
        statement_sources_string = ", ".join(f"'{item}'" for item in statement_sources)
        where_clause += (
            f" AND list_has_any([{statement_sources_string}], statement_sources)"
        )

    data_query = f"""
    SELECT *
    FROM {table}
    WHERE 1 = 1
    {where_clause}
    ORDER BY *
    ;
    """

    logger.debug(data_query)
    df = conn.sql(query=data_query).fetchdf()
    return df

# %%
def db_connection(db_name, default_data_dir="data"):
    # Connect to the database
    if db_name.startswith("md:"):
        mother_duck_token = os.getenv("MOTHER_DUCK_TOKEN")
        conn = duckdb.connect(
            f"{db_name}?motherduck_token={mother_duck_token}", read_only=True
        )
    else:
        conn = duckdb.connect(f"{default_data_dir}/{db_name}", read_only=True)

    return conn, db_name

# %% [markdown]
# ### Utils

# %%
def now_as_xsd_dateTime():
    # Get the current datetime in UTC
    current_time = datetime.utcnow().isoformat()

    # Remove microseconds for compliance
    if '.' in current_time:
        current_time = current_time.split('.')[0]

    # Append the UTC timezone indicator
    current_time += 'Z'

    return current_time

# %%
def remove_section_symbol(input_string: str) -> str:
    """
    Removes the '§' symbol from the input string and trims whitespace.

    Args:
        input_string (str): The string from which to remove the '§' symbol.

    Returns:
        str: The cleaned string without the '§' symbol and leading/trailing whitespace.

    Raises:
        TypeError: If 'input_string' is not a string.
    """
    if not isinstance(input_string, str):
        raise TypeError("input_string must be a string")
    return input_string.replace("§", "").strip()

# %%
def signifier_sources(sources: list) -> list:
    """
    Extract desgnations sources

    Args:
        sources (list): List of sources

    Returns:
        list: List of sources
    """
    # Extract desgnations sources
    sources_lst = []
    for source in sources:
        source_section = str(source.get("section"))
        source_paragraph = str(source.get("paragraph"))
        sources_lst.append(source_section + source_paragraph)
    return sources_lst

# %%
def normalize_ns_string(input_string: str) -> str:
    """
    Transform the input string to title case, which capitalizes the first letter of each word.

    Args:
        input_string (str): The string to normalize.

    Returns:
        normalized_string (str): The normalized string.
    """
    normalized_string = remove_section_symbol(input_string)

    # Remove all spaces, change points and hyphens to underscores
    return normalized_string.replace(" ", "").replace("-", "_").replace(".", "_")

# %%
def get_metadata_cfr2sbvr(element):
    return {
        "extract_original_statement":element.get('statement_text', 'missing'),
        "transformation_semscore": element.get("semscore", 0),
        "transformation_similarity_score":element.get("similarity_score", 0),
        "transformation_similarity_score_confidence":element.get("similarity_score_confidence", 0),
        "transformation_accuracy":element.get("transformation_accuracy", 0),
        "transformation_grammar_syntax_accuracy":element.get("grammar_syntax_accuracy", 0),
        "transformation_findings":element.get("findings", []),
        # from classification
        "classification_type":element.get("statement_classification_type", 'missing'),
        "classification_subtype":element.get("statement_classification_subtype", 'missing'),
        "classification_type_confidence":element.get("statement_classification_type_confidence", 0),
        "classification_type_explanation":element.get("statement_classification_type_explanation", 'not available'),
        "classification_subtype_confidence":element.get("statement_classification_subtype_confidence", 0),
        "classification_subtype_explanation":element.get("statement_classification_subtype_explanation", 'not available'),
        "classification_templates_ids":element.get("transformation_template_ids", [])
    }

# %% [markdown]
# ### KG functions

# %%
def upsert_section_to_kg(conn: Any,
                   section_chapter: str,
                   section_part: str,
                   section_title: str,
                   section_id: str,
                   section_content: str) -> bool:
    """
    Upserts a section into the Knowledge Graph.

    Args:
        conn (RepositoryConnection): The connection to the Knowledge Graph.
        section_chapter (str): The chapter of the section.
        section_part (str): The part of the section.
        section_title (str): The title of the section.
        section_id (str): The ID of the section.
        section_content (str): The content of the section.

    Returns:
        bool: True if the section was upserted successfully, False otherwise.
    """
    # Upsert section into Knowledge Graph
    normalized_id = normalize_ns_string(section_id)
    query = f"""
PREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>

WITH cfr-sbvr:CFR_SBVR_Graph
DELETE {{
    cfr-sbvr:{normalized_id} ?p ?o .
}}
INSERT {{
    cfr-sbvr:{normalized_id} a cfr-sbvr:CFRSession ;
        cfr-sbvr:cfrId "{section_id}" ;
        cfr-sbvr:cfrChapter "{section_chapter}" ;
        cfr-sbvr:cfrPart "{section_part}" ;
        cfr-sbvr:cfrTitle "{section_title}" ;
        cfr-sbvr:cfrText \"""{section_content}\""" 
.
}}
WHERE {{
    # Match all existing triples
    OPTIONAL {{ cfr-sbvr:{normalized_id} ?p ?o . }}
}}
    """
    
    logger.debug(f"{query=}")

    try:
        conn.prepareUpdate(QueryLanguage.SPARQL, query).evaluate()
        logger.info(f"Section '{normalized_id}' upserted successfully.")
        return True
    except Exception as e:
        logger.error(f"Failed to upsert section {normalized_id}: {e}")
        return False

# %%
def get_section_from_kg(conn: Any, section_id: str) -> Any:
    """
    Retrieves a section from the Knowledge Graph based on the section number.

    Args:
        conn (RepositoryConnection): The connection to the Knowledge Graph.
        section_id (str): The section number.
      
    Returns:
        dict: The section content.
    """
    # Query section number from KG

    normalized_id = normalize_ns_string(section_id)
    
    query = f"""
PREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>

SELECT ?p ?o
WHERE {{
    cfr-sbvr:{normalized_id} ?p ?o .
}}
    """
    tuple_query = conn.prepareTupleQuery(QueryLanguage.SPARQL, query)
    result = tuple_query.evaluate()

    logger.info(f"result.metadata: {result.metadata}")
    logger.info(f"result.variable_names: {result.variable_names}")

    section_text = ""
    section_part = ""
    section_chapter = ""
    section_title = ""
    section_id = ""

    with result:
        for binding_set in result:
            if str(binding_set.getValue("p")) == '<http://cfr2sbvr.com/cfr#cfrText>':
                section_text = str(binding_set.getValue("o")).replace('"', '')
            if str(binding_set.getValue("p")).replace('"', '') == '<http://cfr2sbvr.com/cfr#cfrPart>':
                section_part = str(binding_set.getValue("o")).replace('"', '')
            if str(binding_set.getValue("p")) == '<http://cfr2sbvr.com/cfr#cfrChapter>':
                section_chapter = str(binding_set.getValue("o")).replace('"', '')
            if str(binding_set.getValue("p")) == '<http://cfr2sbvr.com/cfr#cfrTitle>':
                section_title = str(binding_set.getValue("o")).replace('"', '')
            if str(binding_set.getValue("p")).replace('"', '') == '<http://cfr2sbvr.com/cfr#cfrId>':
                section_id = str(binding_set.getValue("o")).replace('"', '')
        res_dict = {
            "section_text": section_text.replace('\\n', '\n').replace('\\t', '\t'),
            "section_part": section_part,
            "section_chapter": section_chapter,
            "section_title": section_title,
            "section_id": section_id
        } 

        return res_dict

# %%
def transform_to_rdf_subject(input_string: str) -> str:
    """
    Transform the input string to a valid RDF subject by converting it to camel case
    and replacing invalid characters.

    Args:
        input_string (str): The string to transform.

    Returns:
        rdf_subject (str): The transformed RDF subject name.
    """
    # Convert to title case (camel case)
    camel_case_string = ''.join(word.capitalize() for word in input_string.split())
    # Replace invalid characters (retain only alphanumeric and underscore)
    rdf_subject = re.sub(r'[^a-zA-Z0-9_]', '', camel_case_string)

    return rdf_subject

# %%
class Term(BaseModel):
    term: str
    classification: Optional[str]  # Allows additional information about the term

class RuleAndFact(BaseModel):
    statement_id: str
    statement: str
    concept_type: str  # Maps to "element_name" in the structure
    terms: Optional[List[Term]]  # Supports nested terms structure
    verb_symbols: Optional[List[str]]  # Supports verb symbols as a list of strings
    vocabulary_namespace: str  # Maps to a constant or inferred namespace
    sources: Optional[List[str]]
    doc_id: Optional[str]
    metadata_cfr2sbvr: Optional[Dict[str, Any]]

def upsert_rule_and_fact_query(rule_fact_model: RuleAndFact) -> str:
    statement = rule_fact_model.statement
    designation_class = rule_fact_model.statement_id
    concept_type = rule_fact_model.concept_type
    vocabulary_namespace = rule_fact_model.vocabulary_namespace
    doc_id = rule_fact_model.doc_id
    metadata_cfr2sbvr = rule_fact_model.metadata_cfr2sbvr

    if concept_type == "Fact":
        designation_type = "DefinitionalRule"
    else:
        designation_type = "BehavioralBusinessRule"

    # Construct surces triple if sources is provided
    sources_triples = ""
    if rule_fact_model.sources:
        for source in rule_fact_model.sources:
            sources_triples += f'sbvr:referenceSupportsMeaning "{doc_id}{source}" ;\n'

    # Construct exactMatch triple if exactMatch is provided
    terms_triples = ""
    if rule_fact_model.terms:
        for term in rule_fact_model.terms:
            terms_triples += f"cfr-sbvr:hasTerm cfr-sbvr:{transform_to_rdf_subject(term.term)} ;\n"

    # Construct surces triple if sources is provided
    verb_symbols_triples = ""
    if rule_fact_model.verb_symbols:
        for verb_symbol in rule_fact_model.verb_symbols:
            verb_symbols_triples += f'cfr-sbvr:hasVerbSymbol cfr-sbvr:{transform_to_rdf_subject(verb_symbol)} ;\n'

    # Construct metadata triples if metadata_cfr2sbvr is provided
    logger.debug(f'{metadata_cfr2sbvr.get("classification_classification_confidence")=}')
    
    # Olny rules pass for two types of classification, facts are DefinitinalRules per definition
    type_classification = ""
    if concept_type == "Rule":
        type_classification = f"""
            cfr-sbvr:classificationTypeConfidence {metadata_cfr2sbvr.get("classification_type_confidence")} ;
            cfr-sbvr:classificationTypeExplanation "{metadata_cfr2sbvr.get("classification_type_explanation")}" ;
        """
    if statement != "missing":
        finding_triples = ""
        findigs = metadata_cfr2sbvr.get("transformation_findings")
        if findigs is not None and len(findigs) > 0:
            for find in findigs:
                finding_triples += f'cfr-sbvr:transformationFinding "{find}" ;\n'

        templates_triples = ""
        templates = metadata_cfr2sbvr.get("classification_templates_ids")
        if templates is not None and len(templates) > 0:
            for template in templates:
                templates_triples += f'cfr-sbvr:classificationTemplatesId "{template}" ;\n'

    metadata = f"""
        cfr-sbvr:extractOriginalStatement "{metadata_cfr2sbvr.get("extract_original_statement")}" ;
        cfr-sbvr:transformationSemscore {metadata_cfr2sbvr.get("transformation_semscore")} ;
        cfr-sbvr:transformationSimilarityScore {metadata_cfr2sbvr.get("transformation_similarity_score")} ;
        cfr-sbvr:transformationSimilarityScoreConfidence {metadata_cfr2sbvr.get("transformation_similarity_score_confidence")} ;
        cfr-sbvr:transformationAccuracy {metadata_cfr2sbvr.get("transformation_accuracy")} ;
        cfr-sbvr:transformationGrammarSyntaxAccuracy {metadata_cfr2sbvr.get("transformation_grammar_syntax_accuracy")} ;
        cfr-sbvr:classificationType "{metadata_cfr2sbvr.get("classification_type")}" ;
        cfr-sbvr:classificationSubtype "{metadata_cfr2sbvr.get("classification_subtype")}" ;
        {type_classification}
        {finding_triples}
        {templates_triples}
        cfr-sbvr:classificationSubtypeConfidence {metadata_cfr2sbvr.get("classification_subtype_confidence")} ;
        cfr-sbvr:classificationSubtypeExplanation "{metadata_cfr2sbvr.get("classification_subtype_explanation")}" ;
    """

    upsert_query = f"""
PREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>
PREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>

WITH cfr-sbvr:CFR_SBVR
DELETE {{
    cfr-sbvr:{designation_class} ?p ?o .
}}
INSERT {{
    cfr-sbvr:{designation_class} a sbvr:{concept_type},
            sbvr:{designation_type} ;
        {terms_triples}
        {verb_symbols_triples}
        {sources_triples}
        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;
        sbvr:statement "{statement}" ;
        sbvr:designationIsInNamespace {vocabulary_namespace} ;
        {metadata} 
        cfr-sbvr:createDate "{now_as_xsd_dateTime()}"^^xsd:dateTime .
}}
WHERE {{
    # Match all existing triples related to {designation_class}
    OPTIONAL {{ cfr-sbvr:{designation_class} ?p ?o . }}
}}
    """

    return upsert_query

# %% [markdown]
# Class to represent a verb symbol, terms, and names.

# %%
class Designation(BaseModel):
    signifier: str
    statement: str
    concept_type: str
    closeMatch: Optional[List[str]]
    exactMatch: Optional[List[str]]
    vocabulary_namespace: str
    sources: Optional[List[str]]
    doc_id: Optional[str]
    metadata_cfr2sbvr: Optional[Dict[str, Any]]

# %%
def upsert_verb_symbol_query(designation: Designation) -> str:
    signifier = designation.signifier
    transformed_statement = designation.statement
    statement = "missing"

    concept_type = designation.concept_type  # sbvr:VerbConcept
    vocabulary_namespace = designation.vocabulary_namespace
    doc_id = designation.doc_id
    metadata_cfr2sbvr = designation.metadata_cfr2sbvr

    designation_class = transform_to_rdf_subject(
        f"{signifier}-{remove_section_symbol(doc_id)}"
    )

    # Construct surces triple if sources is provided
    sources_triples = ""
    if designation.sources:
        for source in designation.sources:
            sources_triples += f'sbvr:referenceSupportsMeaning "{doc_id}{source}" ;\n'

    # Construct metadata triples if metadata_cfr2sbvr is provided

    metadata = f"""
        cfr-sbvr:extractOriginalStatement "{metadata_cfr2sbvr.get("extract_original_statement")}" ;
        cfr-sbvr:transformedStatement "{transformed_statement}" ;
        cfr-sbvr:createDate "{now_as_xsd_dateTime()}"^^xsd:dateTime ;
    """

    query = f"""
PREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>
PREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>

WITH cfr-sbvr:CFR_SBVR
DELETE {{
    cfr-sbvr:{designation_class} ?p ?o .
}}
INSERT {{
    cfr-sbvr:{designation_class} a sbvr:VerbSymbol,
            sbvr:{concept_type} ;
        sbvr:signifier "{signifier}" ;
        {sources_triples}
        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;
        sbvr:statement "{statement}" ;
        sbvr:designationIsInNamespace {vocabulary_namespace} ;
        {metadata} .
}}
WHERE {{
    # Match all existing triples related to {designation_class}
    OPTIONAL {{ cfr-sbvr:{designation_class} ?p ?o . }}
}}
    """

    return query

# %%
def upsert_term_and_name_query(designation: Designation) -> str:
    """
    Add a term to the knowledge graph. If exists, replace it.

    Args:
        conn (RepositoryConnection): The connection to the knowledge graph database.
        term (Term): The term to add to the knowledge graph.

    Returns:
        True if the term was added successfully, False otherwise.
    """
    signifier = designation.signifier
    statement = designation.statement
    concept_type = designation.concept_type
    vocabulary_namespace = designation.vocabulary_namespace
    doc_id = designation.doc_id
    metadata_cfr2sbvr = designation.metadata_cfr2sbvr

    designation_class = transform_to_rdf_subject(f"{signifier}-{remove_section_symbol(doc_id)}")

    if concept_type == "Name":
        designation_type = "IndividualNounConcept"
    else:
        designation_type = "GeneralConcept"

    logger.info(f"Format {signifier} to {designation_class}.")

    # Rule type
    match metadata_cfr2sbvr.get("classification_subtype"):
        case "Formal intensional definitions":
            rule_type = "sbvr:IntensionalDefinition"
        case "Formal extensional definitions":
            rule_type = "sbvr:Extensionaldefinition"
        case "Categorization scheme enumerations":
            rule_type = "sbvr:Categorizationscheme"
        case _:
            rule_type = "sbvr:DefinitionalRule"

    # Constructing closeMatch triples
    close_matches_triples = ""
    if designation.closeMatch:
        for close_match in designation.closeMatch:
            close_matches_triples += f"sbvr:closeMatch {close_match} ;\n"

    # Construct exactMatch triple if exactMatch is provided
    exact_match_triples = ""
    if designation.exactMatch:
        for exact_match in designation.exactMatch:
            exact_match_triples += f"sbvr:exactMatch {exact_match} ;\n"

    # Construct surces triple if sources is provided
    sources_triples = ""
    if designation.sources:
        for source in designation.sources:
            sources_triples += f'sbvr:referenceSupportsMeaning "{doc_id}{source}" ;\n'

    # Construct metadata triples if metadata_cfr2sbvr is provided
    metadata = ""
    if statement != "missing":
        finding_triples = ""
        findigs = metadata_cfr2sbvr.get("transformation_findings")
        if findigs is not None and len(findigs) > 0:
            for find in findigs:
                finding_triples += f'cfr-sbvr:transformationFinding "{find}" ;\n'

        templates_triples = ""
        templates = metadata_cfr2sbvr.get("classification_templates_ids")
        if templates is not None and len(templates) > 0:
            for template in templates:
                templates_triples += f'cfr-sbvr:classificationTemplatesId "{template}" ;\n'

        metadata = f"""
            cfr-sbvr:extractOriginalStatement "{metadata_cfr2sbvr.get("extract_original_statement")}" ;
            cfr-sbvr:transformationSemscore {metadata_cfr2sbvr.get("transformation_semscore")} ;
            cfr-sbvr:transformationSimilarityScore {metadata_cfr2sbvr.get("transformation_similarity_score")} ;
            cfr-sbvr:transformationSimilarityScoreConfidence {metadata_cfr2sbvr.get("transformation_similarity_score_confidence")} ;
            cfr-sbvr:transformationAccuracy {metadata_cfr2sbvr.get("transformation_accuracy")} ;
            cfr-sbvr:transformationGrammarSyntaxAccuracy {metadata_cfr2sbvr.get("transformation_grammar_syntax_accuracy")} ;
            {finding_triples}
            {templates_triples}
            cfr-sbvr:classificationType "{metadata_cfr2sbvr.get("classification_type")}" ;
            cfr-sbvr:classificationSubtype "{metadata_cfr2sbvr.get("classification_subtype")}" ;
            cfr-sbvr:classificationSubtypeConfidence {metadata_cfr2sbvr.get("classification_subtype_confidence")} ;
            cfr-sbvr:classificationSubtypeExplanation "{metadata_cfr2sbvr.get("classification_subtype_explanation")}" ;
        """

    designation_upsert_query = f"""
PREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>
PREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>

WITH cfr-sbvr:CFR_SBVR
DELETE {{
    cfr-sbvr:{designation_class} ?p ?o .
}}
INSERT {{
    cfr-sbvr:{designation_class} a sbvr:{designation_type},
            {rule_type},
            sbvr:{concept_type} ;
        sbvr:signifier "{signifier}" ;
        {exact_match_triples}
        {close_matches_triples}
        {sources_triples}
        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;
        sbvr:statement "{statement}" ;
        sbvr:designationIsInNamespace {vocabulary_namespace} ;
        {metadata}
        cfr-sbvr:createDate "{now_as_xsd_dateTime()}"^^xsd:dateTime .
}}
WHERE {{
    # Match all existing triples related to {designation_class}
    OPTIONAL {{ cfr-sbvr:{designation_class} ?p ?o . }}
}}
    """

    return designation_upsert_query

# %%
def upsert_to_kg(conn: RepositoryConnection, query: str) -> bool:
    try:
        conn.prepareUpdate(QueryLanguage.SPARQL, query).evaluate()
        logger.info("Upserted successfully.")
        return True
    except Exception as e:
        logger.error(f"Failed to upsert: {e}")
        return False

# %%
def create_vocabulary(conn: RepositoryConnection, vocabulary_name: str) -> bool:
    """
    Create a new vocabulary in the knowledge graph.

    Args:
        conn (RepositoryConnection): The connection to the knowledge graph database.
        vocabulary (str): The name of the vocabulary to create.

    Returns:
        True if the vocabulary was created successfully, False otherwise.
    """

    query_remove_association = f"""
PREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>
PREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>

DELETE DATA {{
GRAPH cfr-sbvr:CFR_SBVR {{
    fro-cfr:CFR_Title_17_Part_275_VOC sbvr:vocabulary1IncorporatesVocabulary2 cfr-sbvr:CFR_SBVR_{vocabulary_name}_VOC .
}}
}}
    """

    query_add_triples = f"""
PREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>
PREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>

WITH cfr-sbvr:CFR_SBVR
DELETE {{
    cfr-sbvr:CFR_SBVR_{vocabulary_name}_VOC ?p ?o .
}}

INSERT {{
    cfr-sbvr:CFR_SBVR_{vocabulary_name}_VOC
        a owl:Class, sbvr:Vocabulary ;
        cfr-sbvr:createDate "{now_as_xsd_dateTime()}"^^xsd:dateTime .
}}
WHERE {{
    # Match all existing triples related to cfr-sbvr:CFR_SBVR_{vocabulary_name}_VOC
    OPTIONAL {{ cfr-sbvr:CFR_SBVR_{vocabulary_name}_VOC ?p ?o . }}
}}
    """

    query_add_association = f"""
PREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>
PREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>

INSERT DATA {{
GRAPH cfr-sbvr:CFR_SBVR {{
    fro-cfr:CFR_Title_17_Part_275_VOC sbvr:vocabulary1IncorporatesVocabulary2 cfr-sbvr:CFR_SBVR_{vocabulary_name}_VOC .
}}
}}
    """

    logger.debug(f"SPARQL Query: {query_remove_association}")
    logger.debug(f"SPARQL Query: {query_add_triples}")
    logger.debug(f"Vocabulary name: cfr-sbvr:CFR_SBVR_{vocabulary_name}_VOC")

    # Remove associated vocabulary
    try:
        conn.prepareUpdate(QueryLanguage.SPARQL, query_remove_association).evaluate()
        logger.info(f"Vocabulary {vocabulary_name} delete associated successfully.")
    except Exception as e:
        logger.error(f"Failed to delete associated vocabulary {vocabulary_name}: {e}")

    # create new vocabulary
    try:
        conn.prepareUpdate(QueryLanguage.SPARQL, query_add_triples).evaluate()
        logger.info(f"Vocabulary {vocabulary_name} created successfully.")
    except Exception as e:
        logger.error(f"Failed to create vocabulary {vocabulary_name}: {e}")

    # Add association with new vocabulary
    try:
        conn.prepareUpdate(QueryLanguage.SPARQL, query_add_association).evaluate()
        logger.info(f"Vocabulary {vocabulary_name} associated successfully.")
        return True
    except Exception as e:
        logger.error(f"Failed to associate vocabulary {vocabulary_name}: {e}")
        return False

# %%
def create_vocabulary_namespace(conn: RepositoryConnection, vocabulary_name: str) -> bool:
    """
    Create a new vocabulary namespace in the knowledge graph.

    Args:
        conn (RepositoryConnection): The connection to the knowledge graph database.
        vocabulary_namespace (str): The name of the vocabulary namespace to create.

    Returns:
        True if the vocabulary namespace was created successfully, False otherwise.
    """

    query_remove_association = f"""
PREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>
PREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>

DELETE DATA {{
GRAPH cfr-sbvr:CFR_SBVR {{
    fro-cfr:CFR_Title_17_Part_275_NS sbvr:namespace1IncorporatesNamespace2 cfr-sbvr:CFR_SBVR_{vocabulary_name}_NS .
}}
}}
    """

    query_add_triples = f"""
PREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>
PREFIX dct: <http://purl.org/dc/terms/>
PREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>

WITH cfr-sbvr:CFR_SBVR
DELETE {{
    cfr-sbvr:CFR_SBVR_{vocabulary_name}_NS ?p ?o .
}}

INSERT {{
cfr-sbvr:CFR_SBVR_{vocabulary_name}_NS
        a owl:Class, sbvr:VocabularyNamespace;
    sbvr:namespaceHasURI <http://cfr2sbvr.com/cfr/CFR_SBVR_{vocabulary_name}_NS#> ;
    sbvr:vocabularyIsExpressedInLanguage cfr-sbvr:EnglishLanguage ;
    sbvr:vocabularyNamespaceIsDerivedFromVocabulary cfr-sbvr:CFR_SBVR_{vocabulary_name}_VOC ;
    dct:title "Semantics of Business Vocabulary and Business Rules (SBVR) for Code of Federal Regulations (CFR)" ;
    skos:definition "SBVR-CFR is an adopted standard of the Object Management Group (OMG) intended to be the basis for formal and detailed natural language declarative description of CFR regulations" ;
    dct:source <https://github.com/asantos2000/dissertacao-santos-anderson-2024> ;
    cfr-sbvr:createDate "{now_as_xsd_dateTime()}"^^xsd:dateTime .
}}
WHERE {{
    # Match all existing triples related to cfr-sbvr:CFR_SBVR_{vocabulary_name}_NS
    OPTIONAL {{ cfr-sbvr:CFR_SBVR_{vocabulary_name}_NS ?p ?o . }}
}}
    """
    query_add_association = f"""
PREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>
PREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>

INSERT DATA {{
GRAPH cfr-sbvr:CFR_SBVR {{
    fro-cfr:CFR_Title_17_Part_275_NS sbvr:namespace1IncorporatesNamespace2 cfr-sbvr:CFR_SBVR_{vocabulary_name}_NS .
}}
}}
    """

    logger.debug(f"SPARQL Query: {query_remove_association}")
    logger.debug(f"SPARQL Query: {query_add_triples}")
    logger.debug(f"SPARQL Query: {query_add_association}")

    # Remove associated vocabulary
    try:
        conn.prepareUpdate(QueryLanguage.SPARQL, query_remove_association).evaluate()
        logger.info(f"Vocabulary NS {vocabulary_name} delete associated successfully.")
    except Exception as e:
        logger.error(f"Failed to delete associated vocabulary NS {vocabulary_name}: {e}")

    # create new vocabulary
    try:
        conn.prepareUpdate(QueryLanguage.SPARQL, query_add_triples).evaluate()
        logger.info(f"Vocabulary NS {vocabulary_name} created successfully.")
    except Exception as e:
        logger.error(f"Failed to create vocabulary NS {vocabulary_name}: {e}")

    # Add association with new vocabulary
    try:
        conn.prepareUpdate(QueryLanguage.SPARQL, query_add_association).evaluate()
        logger.info(f"Vocabulary NS {vocabulary_name} associated successfully.")
        return True
    except Exception as e:
        logger.error(f"Failed to associate vocabulary NS {vocabulary_name}: {e}")
        return False

# %%
def define_vocabulary_ns(conn: RepositoryConnection, doc_id: str, is_local_scope: bool) -> str:
    """
    Determines the vocabulary section ID based on the term's source section.

    Args:
        section_id (str): The section ID of the current document.
        source_section: The section id.

    Returns:
        str: The appropriate vocabulary section ID.

    Raises:
        KeyError: If 'source' or 'section' key is missing in the term.
        TypeError: If 'section_id' is not a string or 'term' is not a dictionary.
    """

    doc_id = remove_section_symbol(normalize_ns_string(doc_id))

    if is_local_scope:
        ns = f"cfr-sbvr:CFR_SBVR_{doc_id}_NS"
    else:
        ns = "fro-cfr:CFR_Title_17_Part_275_NS"

    query = f"""
        PREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>
        PREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>

        select ?p ?o {{
            graph cfr-sbvr:CFR_SBVR {{
                {ns} ?p ?o 
            }}
        }}
    """

    tuple_query = conn.prepareTupleQuery(QueryLanguage.SPARQL, query)
    result = tuple_query.evaluate()

    logger.debug(f"result.metadata: {result.metadata}")
    logger.debug(f"result.variable_names: {result.variable_names}")

    for binding in result:
        logger.debug(f"binding: {binding}")

    if not result:
        # Vocabulary
        logger.info("Vocabulary not found. Creating vocabulary and namespace...")
        if create_vocabulary(conn, doc_id):
            logger.info("Vocabulary created")
        else:
            raise Exception("Failed to create vocabulary")

        # Vocabulary namespace
        if create_vocabulary_namespace(conn, doc_id):
            logger.info("Vocabulary namespace created")
        else:
            raise Exception("Failed to create vocabulary namespace")
    else:
        logger.info("Vocabulary already exists")
    
    logger.info(f"Vocabulary namespace: {ns}")
    
    return ns

# %% [markdown]
# similarity search (P5)
#
# Try a similarity search to find the entity in the graph. If not found, create a new entity and corresponding embedding. If exists, create a link between the two.

# %%
def get_from_kg(conn: RepositoryConnection, signifier: str, kg: str, vector_db: str) -> List[Dict[str, Any]]:
    """
    Queries the knowledge graph to retrieve similar terms to the given term.

    Args:
        conn (RepositoryConnection): The AllegroGraph repository connection.
        term (str): The term to search for similar terms in the knowledge graph.
        kg (str): The name of the knowledge graph to query.

    Returns:
        List[Dict[str, Any]]: A list of dictionaries containing information about similar terms,
        including URIs, scores, definitions, and related predicates.
    """

    if kg not in {config["FIBO_GRAPH"], config["CFR_SBVR_GRAPH"]}:
        raise ValueError(f"Unsupported knowledge graph: {kg}")

    query_string = f"""
PREFIX llm: <http://franz.com/ns/allegrograph/8.0.0/llm/>
PREFIX fibo: <https://spec.edmcouncil.org/fibo/ontology/master/2024Q2/QuickFIBOProd#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>
PREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>

SELECT ?uri (xsd:decimal(?score) as ?score_percent) ?s ?p ?definition
FROM {kg}
WHERE {{
    (?uri ?score ?originalText ?p) llm:nearestNeighbor ("{signifier}" "{vector_db}" 5 0.85) .
    # ?s ?p ?originalText .

    OPTIONAL {{ ?s skos:definition ?definition . }}
    OPTIONAL {{ ?s sbvr:Statement ?definition . }}
}}
ORDER BY DESC(?score)
    """

    logger.debug(f"SPARQL Query: {query_string}")

    tuple_query = conn.prepareTupleQuery(QueryLanguage.SPARQL, query_string)

    try:
        result = tuple_query.evaluate()
        logger.debug(f"Result metadata: {result.metadata}")

        with result:
            similar_signifiers = [
                {
                    "uri": str(binding.getValue("uri")),
                    "score_percent": Decimal(binding.getValue("score_percent").getLabel()),
                    "located_signifier_uri": str(binding.getValue("s")),
                    "located_signifier_uri_local_name": binding.getValue("s").getLocalName(),
                    "located_signifier_predicate": str(binding.getValue("p")),
                    "definition": str(binding.getValue("definition"))
                }
                for binding in result
            ]
    except Exception as e:
        logger.error(f"Error evaluating SPARQL query: {e}")
        raise

    logger.info(f"Found {len(similar_signifiers)} similar signifier(s) for '{signifier}' on {kg}.")

    return similar_signifiers

# %%
def get_similar_signifiers(conn: RepositoryConnection, signifier: str) -> Tuple[list]:
    """
    Get similar signifiers for a given signifier.

    Args:
        conn (allegrograph.AllegroGraphConnection): An AllegroGraph connection object.
        signifier (str): The signifier to search for.

    Returns:
        list (Tuple[list]): A list of exact and close matches for the signifier.
    """
    fibo_similarity =  get_from_kg(conn, signifier, config["FIBO_GRAPH"], config["FIBO_GRAPH_VECTOR_STORE"])
    cfr_sbvr_similarity = get_from_kg(conn, signifier, config["CFR_SBVR_GRAPH"], config["CFR_SBVR_GRAPH_VECTOR_STORE"])

    exact_match = []
    close_match = []

    for item in fibo_similarity:
        logger.info(f"{item=}")
        if item["score_percent"] > config["SIMILARITY_THRESHOLD"]:
            exact_match.append(item.get("located_signifier_uri"))
        else:
            close_match.append(item.get("located_signifier_uri"))

    for item in cfr_sbvr_similarity:
        if item["score_percent"] > config["SIMILARITY_THRESHOLD"]:
            exact_match.append(item.get("located_signifier_uri"))
        else:
            close_match.append(item.get("located_signifier_uri"))

    logger.info(f"Found {len(exact_match)} exact matche(s) and {len(close_match)} close matche(s) for '{signifier}'.")

    return exact_match, close_match

# %% [markdown]
# Generate a RDF subject from a statement.

# %%
def to_camel_case(snake_str):
    """
    Convert a snake_case string to CamelCase.
    """
    components = snake_str.split("_")
    return "".join(x.title() for x in components)


def generate_meaningful_rdf_subject(statement, domain_context=""):
    """
    Generate a meaningful and descriptive RDF subject from a statement in CamelCase.

    Args:
        statement (str): The input sentence or statement.
        domain_context (str): Additional domain context for enrichment.

    Returns:
        str: A rich, meaningful RDF subject in CamelCase.
    """
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(statement)

    # Initialize components
    main_subject = None
    predicate = None
    obj = None
    attributes = []

    # Extract subject, verb (predicate), and object
    for token in doc:
        if token.dep_ in ("nsubj", "nsubjpass") and not main_subject:
            main_subject = token.text
        elif token.pos_ == "VERB" and not predicate:
            predicate = token.lemma_  # Base form of the verb
        elif token.dep_ in ("dobj", "pobj") and not obj:
            obj = token.text

    # Extract additional attributes (e.g., named entities or adjectives)
    attributes.extend(
        [ent.text for ent in doc.ents if ent.label_ in {"ORG", "GPE", "LAW", "EVENT"}]
    )
    attributes.extend([token.text for token in doc if token.pos_ == "ADJ"])

    # Combine extracted components
    components = [main_subject, predicate, obj] + attributes
    if domain_context:
        components.append(domain_context)

    # Filter out None, empty values, and repetitions
    logger.debug(f"{components=}")

    # Filter out None, empty values, and repetitions
    components = [
        comp for i, comp in enumerate(components)
        if comp and isinstance(comp, str) and (i == 0 or not components[i-1] or isinstance(components[i-1], str) and comp.lower() != components[i-1].lower())
    ]


    # Normalize to snake_case, then convert to CamelCase
    snake_case_subject = slugify("_".join(components), separator="_")
    camel_case_subject = to_camel_case(snake_case_subject)

    return camel_case_subject

# %% [markdown]
# ## Datasets

# %%
hosting = config["ALLEGROGRAPH_HOSTING"]

# %% [markdown]
# Workaround to connect AllegroGraph Cloud via stunnel.
#
# > Configure the host using the connect variable.

# %%
# %%writefile agraph_stunnel.conf
#
# [allegrograph_proxy]
# client = yes
# accept = 127.0.0.1:8443
# connect = ag1eawvuu0p3zv35.allegrograph.cloud:443

# %%
if hosting == "ALLEGROGRAPH_CLOUD":
    # Start tunnel
    import getpass
    import os

    password = getpass.getpass()
    command = "sudo -S stunnel agraph_stunnel.conf" #can be any command but don't forget -S as it enables input from stdin
    os.system('echo %s | %s' % (password, command)) # Start stunnel

    config[hosting]["HOST"]="localhost"
    config[hosting]["PORT"]=8443
    config[hosting]["PROTOCOL"]="http"
# Out:
# [ ] Initializing inetd mode configuration
# [ ] Clients allowed=500
# [.] stunnel 5.72 on x86_64-pc-linux-gnu platform
# [.] Compiled/running with OpenSSL 3.0.13 30 Jan 2024
# [.] Threading:PTHREAD Sockets:POLL,IPv6,SYSTEMD TLS:ENGINE,OCSP,PSK,SNI Auth:LIBWRAP
# [ ] errno: (*__errno_location ())
# [ ] Initializing inetd mode configuration
# [.] Reading configuration from file /mnt/d/Projects/dissertacao-santos-anderson-2024/code/labs/agraph_stunnel.conf
# [.] UTF-8 byte order mark not detected
# [.] FIPS mode disabled
# [ ] Compression disabled
# [ ] No PRNG seeding was required
# [ ] Initializing service [allegrograph_proxy]
# [ ] Initializing context [allegrograph_proxy]
# [ ] OpenSSL security level is used: 2
# [ ] Ciphers: HIGH:!aNULL:!SSLv2:!DH:!kDHEPSK
# [ ] TLSv1.3 ciphersuites: TLS_AES_256_GCM_SHA384:TLS_AES_128_GCM_SHA256:TLS_CHACHA20_POLY1305_SHA256
# [ ] TLS options: 0x2100000 (+0x0, -0x0)
# [ ] Session resumption enabled
# [ ] No certificate or private key specified
# [ ] No trusted certificates found
# [:] Service [allegrograph_proxy] needs authentication to prevent MITM attacks
# [ ] OCSP: Client OCSP stapling enabled
# [ ] DH initialization skipped: client section
# [ ] ECDH initialization
# [ ] ECDH initialized with curves X25519:P-256:X448:P-521:P-384
# [.] Configuration successful
# [ ] Deallocating deployed section defaults
# [ ] Cleaning up context [stunnel]
# [ ] Binding service [allegrograph_proxy]
# [ ] Listening file descriptor created (FD=9)
# [ ] Setting accept socket options (FD=9)
# [ ] Option SO_REUSEADDR set on accept socket
# [.] Binding service [allegrograph_proxy] to 127.0.0.1:8443: Address already in use (98)
# [!] Binding service [allegrograph_proxy] failed
# [ ] Unbinding service [allegrograph_proxy]
# [ ] Service [allegrograph_proxy] closed
# [ ] Deallocating deployed section defaults
# [ ] Cleaning up context [stunnel]
# [ ] Deallocating section [allegrograph_proxy]
# [ ] Cleaning up context [allegrograph_proxy]
# [ ] Initializing inetd mode configuration

# %% [markdown]
# ### Connect KG

# %%
kg_conn = ag_connect(
    repo=config[hosting]["REPO"],
    catalog=config[hosting]["CATALOG"],
    host=config[hosting]["HOST"],
    port=config[hosting]["PORT"],
    protocol=config[hosting]["PROTOCOL"],
    user=config[hosting]["USER"],
    password=config[hosting]["PASSWORD"],
)

logger.info(f"Connected to AllegroGraph: {hosting}")
# Out:
# 2025-01-30 19:15:15 - INFO - Connected to AllegroGraph: ALLEGROGRAPH_CLOUD

# %% [markdown]
# ### Connect DB

# %%
DEFAULT_DATA_DIR = "../cfr2sbvr_inspect/data"
DATABASE = "cfr2sbvr_v4.db"

db_conn, db_name = db_connection(DATABASE, DEFAULT_DATA_DIR)

table_selected = "RAW_LLM_VALIDATION_BEST_VW"
checkpoints_selected = None
doc_id_selected = None
statement_sources_selected = None
process_selected = None

# %% [markdown]
# ### Load data

# %%
#
# Load the selected data
#
data_df = load_data(
    db_conn,
    table_selected,
    checkpoints_selected,
    doc_id_selected,
    statement_sources_selected,
    process_selected,
)

# %% [markdown]
# Prepare dictionaries with the best results.

# %%
pred_terms_names = data_df[data_df['source'].isin(['Terms','Names'])].to_dict(orient="records")
pred_operative_rules_fact_types = data_df[data_df['source'].isin(['Operative_Rules','Fact_Types'])].to_dict(orient="records")

# %% [markdown]
# ## Execution

# %% [markdown]
# ### Terms and names

# %%
for index, element in enumerate(pred_terms_names):

    logger.info(f"{index=}")

    # from extraction
    doc_id = element.get('doc_id') # section

    statement_id = element.get('statement_id')
    
    statement = element.get('transformed')
    statement = statement if statement else "missing" # Change None to "missing"

    # SBVR ontology
    concept_type = "Term" if element.get('source') == "Terms" else "Name"
    
    sources = element.get("statement_sources") # paragraphs
    
    is_local_scope = element.get("isLocalScope")
    
    # from transformation
    metadata_cfr2sbvr = get_metadata_cfr2sbvr(element)

    # create vocabulary and namespace if not exists
    vocabulary = define_vocabulary_ns(kg_conn, doc_id, is_local_scope)

    # similar search
    exact_match, close_match = get_similar_signifiers(kg_conn, statement_id)

    # create designation
    designation = Designation(
        signifier=statement_id,
        statement=statement,
        concept_type=concept_type,
        closeMatch=close_match,
        exactMatch=exact_match,
        vocabulary_namespace=vocabulary,
        sources=sources,
        doc_id=doc_id,
        metadata_cfr2sbvr=metadata_cfr2sbvr
    )

    # upsert
    query = upsert_term_and_name_query(designation)
    logger.info(f"{query=}")
    status = upsert_to_kg(kg_conn, query)

    logger.info(f"{concept_type} '{statement_id}' done.")
# Out:
# 2025-01-30 19:37:07 - INFO - index=0
# 2025-01-30 19:37:11 - INFO - Vocabulary already exists
# 2025-01-30 19:37:11 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:37:11 - INFO - Found 0 similar signifier(s) for 'Commission' on fibo:FIBO_Graph.
# 2025-01-30 19:37:11 - INFO - Found 0 similar signifier(s) for 'Commission' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:11 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Commission'.
# 2025-01-30 19:37:11 - INFO - Format Commission to Commission27505.
# 2025-01-30 19:37:11 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Commission27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Commission27505 a sbvr:IndividualNounConcept,\n            sbvr:IntensionalDefinition,\n            sbvr:Name ;\n        sbvr:signifier "Commission" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-5(b)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-5(d)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-5(a)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-5(c)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A Commission is by definition a regulatory body that is responsible for issuing orders and conducting hearings." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "The regulatory body responsible for issuing orders and conducting hearings." ;\n            cfr-sbvr:transformationSemscore 0.8314100742712213 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.95 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original definition with the structure provided by the template." ;\ncfr-sbvr:transformationFinding "The use of \'A Commission is by definition a regulatory body that is responsible for issuing orders and conducting hearings.\' maintains the meaning and intent of the original statement." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:11Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to Commission27505\n    OPTIONAL { cfr-sbvr:Commission27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:11 - INFO - Upserted successfully.
# 2025-01-30 19:37:11 - INFO - Name 'Commission' done.
# 2025-01-30 19:37:11 - INFO - index=1
# 2025-01-30 19:37:12 - INFO - Vocabulary already exists
# 2025-01-30 19:37:12 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:37:12 - INFO - Found 0 similar signifier(s) for 'Secretary' on fibo:FIBO_Graph.
# 2025-01-30 19:37:12 - INFO - Found 0 similar signifier(s) for 'Secretary' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:12 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Secretary'.
# 2025-01-30 19:37:12 - INFO - Format Secretary to Secretary27502.
# 2025-01-30 19:37:12 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Secretary27502 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Secretary27502 a sbvr:IndividualNounConcept,\n            sbvr:DefinitionalRule,\n            sbvr:Name ;\n        sbvr:signifier "Secretary" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-2(a)(3)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A Secretary of the Commission is by definition a person who is responsible for forwarding copies of process, pleadings, or other papers to each named party by registered or certified mail." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "The Secretary of the Commission is responsible for forwarding copies of process, pleadings, or other papers to each named party by registered or certified mail." ;\n            cfr-sbvr:transformationSemscore 0.902113515778717 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.9 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original statement with the structure provided by the template." ;\ncfr-sbvr:transformationFinding "The use of \'A Secretary of the Commission\' instead of \'The Secretary of the Commission\' slightly changes the specificity but maintains the overall meaning." ;\ncfr-sbvr:transformationFinding "The transformation maintains the grammatical structure and syntax of the original statement." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal term definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:12Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to Secretary27502\n    OPTIONAL { cfr-sbvr:Secretary27502 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:12 - INFO - Upserted successfully.
# 2025-01-30 19:37:12 - INFO - Name 'Secretary' done.
# 2025-01-30 19:37:12 - INFO - index=2
# 2025-01-30 19:37:12 - INFO - Vocabulary already exists
# 2025-01-30 19:37:12 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:37:12 - INFO - Found 0 similar signifier(s) for 'Secretary of the Commission' on fibo:FIBO_Graph.
# 2025-01-30 19:37:13 - INFO - Found 0 similar signifier(s) for 'Secretary of the Commission' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:13 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Secretary of the Commission'.
# 2025-01-30 19:37:13 - INFO - Format Secretary of the Commission to SecretaryOfTheCommission27502.
# 2025-01-30 19:37:13 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:SecretaryOfTheCommission27502 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:SecretaryOfTheCommission27502 a sbvr:IndividualNounConcept,\n            sbvr:DefinitionalRule,\n            sbvr:Name ;\n        sbvr:signifier "Secretary of the Commission" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-2(a)(2)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A Secretary of the Commission is by definition a person who is responsible for forwarding copies of process, pleadings, or other papers to each named party by registered or certified mail." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "The Secretary of the Commission is responsible for forwarding copies of process, pleadings, or other papers to each named party by registered or certified mail." ;\n            cfr-sbvr:transformationSemscore 0.883465517964449 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.9 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original statement with the structure provided by the template." ;\ncfr-sbvr:transformationFinding "The use of \'A Secretary of the Commission\' instead of \'The Secretary of the Commission\' slightly changes the specificity but maintains the overall meaning." ;\ncfr-sbvr:transformationFinding "The transformation maintains the original meaning and intent of the statement." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal term definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:13Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to SecretaryOfTheCommission27502\n    OPTIONAL { cfr-sbvr:SecretaryOfTheCommission27502 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:13 - INFO - Upserted successfully.
# 2025-01-30 19:37:13 - INFO - Name 'Secretary of the Commission' done.
# 2025-01-30 19:37:13 - INFO - index=3
# 2025-01-30 19:37:13 - INFO - Vocabulary already exists
# 2025-01-30 19:37:13 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:37:13 - INFO - Found 0 similar signifier(s) for 'Commission' on fibo:FIBO_Graph.
# 2025-01-30 19:37:13 - INFO - Found 0 similar signifier(s) for 'Commission' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:13 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Commission'.
# 2025-01-30 19:37:13 - INFO - Format Commission to Commission27505.
# 2025-01-30 19:37:13 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Commission27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Commission27505 a sbvr:IndividualNounConcept,\n            sbvr:IntensionalDefinition,\n            sbvr:Name ;\n        sbvr:signifier "Commission" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-5(a)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-5(d)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-5(c)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-5(b)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A Commission is by definition a regulatory body that is responsible for issuing orders and conducting hearings." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "The regulatory body responsible for issuing orders and conducting hearings." ;\n            cfr-sbvr:transformationSemscore 0.8314103774541939 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.95 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 1.0 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original definition with the structure provided by the template." ;\ncfr-sbvr:transformationFinding "The use of \'A Commission is by definition\' aligns well with the template T7." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:13Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to Commission27505\n    OPTIONAL { cfr-sbvr:Commission27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:13 - INFO - Upserted successfully.
# 2025-01-30 19:37:13 - INFO - Name 'Commission' done.
# 2025-01-30 19:37:13 - INFO - index=4
# 2025-01-30 19:37:13 - INFO - Vocabulary already exists
# 2025-01-30 19:37:13 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:37:14 - INFO - Found 0 similar signifier(s) for 'Federal Register' on fibo:FIBO_Graph.
# 2025-01-30 19:37:14 - INFO - Found 0 similar signifier(s) for 'Federal Register' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:14 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Federal Register'.
# 2025-01-30 19:37:14 - INFO - Format Federal Register to FederalRegister27505.
# 2025-01-30 19:37:14 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:FederalRegister27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:FederalRegister27505 a sbvr:IndividualNounConcept,\n            sbvr:IntensionalDefinition,\n            sbvr:Name ;\n        sbvr:signifier "Federal Register" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-5(a)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A Federal Register is by definition the official journal that publishes the notice of initiation of the proceeding." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "The official journal where the notice of initiation of the proceeding is published." ;\n            cfr-sbvr:transformationSemscore 0.9045825422871229 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.9 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original definition with a slight change in structure." ;\ncfr-sbvr:transformationFinding "The use of \'that publishes\' instead of \'where...is published\' maintains the meaning but alters the phrasing." ;\ncfr-sbvr:transformationFinding "The transformation adheres to the template structure, using \'A Federal Register is by definition...\'" ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:14Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to FederalRegister27505\n    OPTIONAL { cfr-sbvr:FederalRegister27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:14 - INFO - Upserted successfully.
# 2025-01-30 19:37:14 - INFO - Name 'Federal Register' done.
# 2025-01-30 19:37:14 - INFO - index=5
# 2025-01-30 19:37:14 - INFO - Vocabulary already exists
# 2025-01-30 19:37:14 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:37:14 - INFO - Found 0 similar signifier(s) for 'Act' on fibo:FIBO_Graph.
# 2025-01-30 19:37:14 - INFO - Found 0 similar signifier(s) for 'Act' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:14 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Act'.
# 2025-01-30 19:37:14 - INFO - Format Act to Act27505.
# 2025-01-30 19:37:14 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Act27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Act27505 a sbvr:IndividualNounConcept,\n            sbvr:IntensionalDefinition,\n            sbvr:Name ;\n        sbvr:signifier "Act" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-5(d)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "An Act is by definition the legislation under which the Commission operates and applications are filed." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "The legislation under which the Commission operates and applications are filed." ;\n            cfr-sbvr:transformationSemscore 0.909533566448718 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.95 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 1.0 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original definition using the template structure." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\ncfr-sbvr:transformationFinding "The transformation maintains the meaning and intent of the original definition." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:14Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to Act27505\n    OPTIONAL { cfr-sbvr:Act27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:15 - INFO - Upserted successfully.
# 2025-01-30 19:37:15 - INFO - Name 'Act' done.
# 2025-01-30 19:37:15 - INFO - index=6
# 2025-01-30 19:37:15 - INFO - Vocabulary already exists
# 2025-01-30 19:37:15 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:37:15 - INFO - Found 0 similar signifier(s) for 'Hearing' on fibo:FIBO_Graph.
# 2025-01-30 19:37:15 - INFO - Found 0 similar signifier(s) for 'Hearing' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:15 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Hearing'.
# 2025-01-30 19:37:15 - INFO - Format Hearing to Hearing27505.
# 2025-01-30 19:37:15 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Hearing27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Hearing27505 a sbvr:GeneralConcept,\n            sbvr:IntensionalDefinition,\n            sbvr:Term ;\n        sbvr:signifier "Hearing" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-5(b)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-5(a)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-5(c)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A hearing is by definition a proceeding ordered by the Commission if necessary or appropriate in the public interest or for the protection of investors." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "A proceeding ordered by the Commission if necessary or appropriate in the public interest or for the protection of investors." ;\n            cfr-sbvr:transformationSemscore 0.9388905964420434 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.95 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 1.0 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original definition with the structure provided by the template." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\ncfr-sbvr:transformationFinding "The transformation maintains the meaning and intent of the original definition." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:15Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to Hearing27505\n    OPTIONAL { cfr-sbvr:Hearing27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:15 - INFO - Upserted successfully.
# 2025-01-30 19:37:15 - INFO - Term 'Hearing' done.
# 2025-01-30 19:37:15 - INFO - index=7
# 2025-01-30 19:37:15 - INFO - Vocabulary already exists
# 2025-01-30 19:37:15 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:37:16 - INFO - Found 0 similar signifier(s) for 'Initiation of the proceeding' on fibo:FIBO_Graph.
# 2025-01-30 19:37:16 - INFO - Found 0 similar signifier(s) for 'Initiation of the proceeding' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:16 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Initiation of the proceeding'.
# 2025-01-30 19:37:16 - INFO - Format Initiation of the proceeding to InitiationOfTheProceeding27505.
# 2025-01-30 19:37:16 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:InitiationOfTheProceeding27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:InitiationOfTheProceeding27505 a sbvr:GeneralConcept,\n            sbvr:IntensionalDefinition,\n            sbvr:Term ;\n        sbvr:signifier "Initiation of the proceeding" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-5(a)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "An initiation of the proceeding is by definition the process that begins when a notice is published in the Federal Register indicating the earliest date upon which an order disposing of the matter may be entered." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "The process that begins when a notice is published in the Federal Register indicating the earliest date upon which an order disposing of the matter may be entered." ;\n            cfr-sbvr:transformationSemscore 0.9448668396651215 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.95 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 1.0 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original definition with the structure provided by the template." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\ncfr-sbvr:transformationFinding "The transformation maintains the meaning and context of the original statement." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:16Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to InitiationOfTheProceeding27505\n    OPTIONAL { cfr-sbvr:InitiationOfTheProceeding27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:16 - INFO - Upserted successfully.
# 2025-01-30 19:37:16 - INFO - Term 'Initiation of the proceeding' done.
# 2025-01-30 19:37:16 - INFO - index=8
# 2025-01-30 19:37:16 - INFO - Vocabulary already exists
# 2025-01-30 19:37:16 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:37:16 - INFO - Found 0 similar signifier(s) for 'Order' on fibo:FIBO_Graph.
# 2025-01-30 19:37:16 - INFO - Found 0 similar signifier(s) for 'Order' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:16 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Order'.
# 2025-01-30 19:37:16 - INFO - Format Order to Order27505.
# 2025-01-30 19:37:16 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Order27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Order27505 a sbvr:GeneralConcept,\n            sbvr:IntensionalDefinition,\n            sbvr:Term ;\n        sbvr:signifier "Order" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-5(b)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-5(d)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-5(a)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "An Order is by definition a decision that is issued by the Commission disposing of the matter." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "A decision issued by the Commission disposing of the matter." ;\n            cfr-sbvr:transformationSemscore 0.8488403188041594 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.95 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 1.0 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original definition with the structure provided by the template." ;\ncfr-sbvr:transformationFinding "The use of \'by definition\' and \'that is\' aligns with the template\'s structure." ;\ncfr-sbvr:transformationFinding "The transformed sentence is grammatically correct and syntactically accurate." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:16Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to Order27505\n    OPTIONAL { cfr-sbvr:Order27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:16 - INFO - Upserted successfully.
# 2025-01-30 19:37:16 - INFO - Term 'Order' done.
# 2025-01-30 19:37:16 - INFO - index=9
# 2025-01-30 19:37:17 - INFO - Vocabulary already exists
# 2025-01-30 19:37:17 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:17 - INFO - Found 0 similar signifier(s) for 'Control' on fibo:FIBO_Graph.
# 2025-01-30 19:37:17 - INFO - Found 0 similar signifier(s) for 'Control' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:17 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Control'.
# 2025-01-30 19:37:17 - INFO - Format Control to Control27507.
# 2025-01-30 19:37:17 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Control27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Control27507 a sbvr:GeneralConcept,\n            sbvr:IntensionalDefinition,\n            sbvr:Term ;\n        sbvr:signifier "Control" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-7(a)(3)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A control is by definition a power that directly or indirectly directs the management or policies of a person, whether through ownership of securities, by contract, or otherwise." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "The power, directly or indirectly, to direct the management or policies of a person, whether through ownership of securities, by contract, or otherwise." ;\n            cfr-sbvr:transformationSemscore 0.8607530848212421 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.9 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original definition with minor rephrasing." ;\ncfr-sbvr:transformationFinding "The use of \'a power that directly or indirectly directs\' maintains the meaning of the original statement." ;\ncfr-sbvr:transformationFinding "The transformation follows the template structure closely, with the qualifying clause \'whether through ownership of securities, by contract, or otherwise\' correctly included." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:17Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to Control27507\n    OPTIONAL { cfr-sbvr:Control27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:17 - INFO - Upserted successfully.
# 2025-01-30 19:37:17 - INFO - Term 'Control' done.
# 2025-01-30 19:37:17 - INFO - index=10
# 2025-01-30 19:37:17 - INFO - Vocabulary already exists
# 2025-01-30 19:37:17 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:17 - INFO - Found 0 similar signifier(s) for 'Partnership' on fibo:FIBO_Graph.
# 2025-01-30 19:37:18 - INFO - Found 0 similar signifier(s) for 'Partnership' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:18 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Partnership'.
# 2025-01-30 19:37:18 - INFO - Format Partnership to Partnership27507.
# 2025-01-30 19:37:18 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Partnership27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Partnership27507 a sbvr:GeneralConcept,\n            sbvr:IntensionalDefinition,\n            sbvr:Term ;\n        sbvr:signifier "Partnership" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(ii)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A partnership is by definition a person that is presumed to control a partnership if the person has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the partnership." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "A person is presumed to control a partnership if the person has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the partnership." ;\n            cfr-sbvr:transformationSemscore 0.924652046852925 ;\n            cfr-sbvr:transformationSimilarityScore 0.8 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.7 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 0.9 ;\n            cfr-sbvr:transformationFinding "The transformed sentence incorrectly identifies \'A partnership\' as \'a person\', which is a significant deviation from the original meaning." ;\ncfr-sbvr:transformationFinding "The transformation attempts to follow the template structure but fails to accurately represent the original statement\'s intent." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are mostly correct, but the semantic meaning is altered." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:18Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to Partnership27507\n    OPTIONAL { cfr-sbvr:Partnership27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:18 - INFO - Upserted successfully.
# 2025-01-30 19:37:18 - INFO - Term 'Partnership' done.
# 2025-01-30 19:37:18 - INFO - index=11
# 2025-01-30 19:37:18 - INFO - Vocabulary already exists
# 2025-01-30 19:37:18 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:18 - INFO - Found 0 similar signifier(s) for 'Right to vote' on fibo:FIBO_Graph.
# 2025-01-30 19:37:18 - INFO - Found 0 similar signifier(s) for 'Right to vote' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:18 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Right to vote'.
# 2025-01-30 19:37:18 - INFO - Format Right to vote to RightToVote27507.
# 2025-01-30 19:37:18 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:RightToVote27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:RightToVote27507 a sbvr:GeneralConcept,\n            sbvr:IntensionalDefinition,\n            sbvr:Term ;\n        sbvr:signifier "Right to vote" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(iii)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(i)(A)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A person is by definition presumed to control a corporation that directly or indirectly has the right to vote 25 percent or more of a class of the corporation\'s voting securities." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "A person is presumed to control a corporation if the person directly or indirectly has the right to vote 25 percent or more of a class of the corporation\'s voting securities." ;\n            cfr-sbvr:transformationSemscore 0.8577280752115346 ;\n            cfr-sbvr:transformationSimilarityScore 0.9 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.85 ;\n            cfr-sbvr:transformationAccuracy 0.7 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 0.9 ;\n            cfr-sbvr:transformationFinding "The transformed sentence maintains the core meaning of the original statement but introduces a slight ambiguity by changing the structure." ;\ncfr-sbvr:transformationFinding "The transformation uses the template structure but does not fully align with the original statement\'s conditional nature." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct, but the transformation introduces a potential misinterpretation of the original conditional clause." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:18Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to RightToVote27507\n    OPTIONAL { cfr-sbvr:RightToVote27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:18 - INFO - Upserted successfully.
# 2025-01-30 19:37:18 - INFO - Term 'Right to vote' done.
# 2025-01-30 19:37:18 - INFO - index=12
# 2025-01-30 19:37:19 - INFO - Vocabulary already exists
# 2025-01-30 19:37:19 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:19 - INFO - Found 0 similar signifier(s) for 'Total assets' on fibo:FIBO_Graph.
# 2025-01-30 19:37:19 - INFO - Found 0 similar signifier(s) for 'Total assets' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:19 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Total assets'.
# 2025-01-30 19:37:19 - INFO - Format Total assets to TotalAssets27507.
# 2025-01-30 19:37:19 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:TotalAssets27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:TotalAssets27507 a sbvr:GeneralConcept,\n            sbvr:DefinitionalRule,\n            sbvr:Term ;\n        sbvr:signifier "Total assets" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(2)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-7(a)(2)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "The total assets of an investment adviser or other person is by definition calculated as the larger of the total assets shown on the balance sheet of the investment adviser or other person, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "The total assets as shown on the balance sheet of the investment adviser or other person described, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger." ;\n            cfr-sbvr:transformationSemscore 0.9104650961383187 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.9 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original definition, maintaining the meaning and context." ;\ncfr-sbvr:transformationFinding "The transformation uses the template structure effectively, incorporating the necessary elements such as \'The total assets of an investment adviser or other person is by definition calculated as\'." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct, with proper use of conjunctions and clauses." ;\ncfr-sbvr:transformationFinding "The phrase \'whichever is larger\' is effectively transformed into \'the larger of\', maintaining the comparative meaning." ;\n\n            cfr-sbvr:classificationTemplatesId "T16" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Data calculation algorithms" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:19Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to TotalAssets27507\n    OPTIONAL { cfr-sbvr:TotalAssets27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:19 - INFO - Upserted successfully.
# 2025-01-30 19:37:19 - INFO - Term 'Total assets' done.
# 2025-01-30 19:37:19 - INFO - index=13
# 2025-01-30 19:37:19 - INFO - Vocabulary already exists
# 2025-01-30 19:37:19 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:19 - INFO - Found 0 similar signifier(s) for 'Total assets' on fibo:FIBO_Graph.
# 2025-01-30 19:37:20 - INFO - Found 0 similar signifier(s) for 'Total assets' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:20 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Total assets'.
# 2025-01-30 19:37:20 - INFO - Format Total assets to TotalAssets27507.
# 2025-01-30 19:37:20 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:TotalAssets27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:TotalAssets27507 a sbvr:GeneralConcept,\n            sbvr:DefinitionalRule,\n            sbvr:Term ;\n        sbvr:signifier "Total assets" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-7(a)(2)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-7(b)(2)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "The total assets of an investment adviser or other person is by definition calculated as the larger of the total assets shown on the balance sheet of the investment adviser or other person described, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "The total assets as shown on the balance sheet of the investment adviser or other person described, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger." ;\n            cfr-sbvr:transformationSemscore 0.9166169344220211 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.9 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original definition, maintaining the meaning and context." ;\ncfr-sbvr:transformationFinding "The transformation uses the template structure effectively, incorporating the necessary elements such as \'total assets\', \'investment adviser\', and \'balance sheet\'." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct, with proper use of clauses and conjunctions." ;\ncfr-sbvr:transformationFinding "The phrase \'whichever is larger\' is effectively transformed into \'the larger of\', maintaining the comparative aspect." ;\n\n            cfr-sbvr:classificationTemplatesId "T16" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Data calculation algorithms" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:20Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to TotalAssets27507\n    OPTIONAL { cfr-sbvr:TotalAssets27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:20 - INFO - Upserted successfully.
# 2025-01-30 19:37:20 - INFO - Term 'Total assets' done.
# 2025-01-30 19:37:20 - INFO - index=14
# 2025-01-30 19:37:20 - INFO - Vocabulary already exists
# 2025-01-30 19:37:20 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:37:20 - INFO - Found 0 similar signifier(s) for 'Managing agent' on fibo:FIBO_Graph.
# 2025-01-30 19:37:20 - INFO - Found 0 similar signifier(s) for 'Managing agent' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:20 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Managing agent'.
# 2025-01-30 19:37:20 - INFO - Format Managing agent to ManagingAgent27502.
# ...
# 2025-01-30 19:37:27 - INFO - Upserted successfully.
# 2025-01-30 19:37:27 - INFO - Term 'Trust' done.
# 2025-01-30 19:37:27 - INFO - index=25
# 2025-01-30 19:37:27 - INFO - Vocabulary already exists
# 2025-01-30 19:37:27 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:37:27 - INFO - Found 0 similar signifier(s) for 'Commission's records' on fibo:FIBO_Graph.
# 2025-01-30 19:37:27 - INFO - Found 0 similar signifier(s) for 'Commission's records' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:27 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Commission's records'.
# 2025-01-30 19:37:27 - INFO - Format Commission's records to CommissionsRecords27502.
# 2025-01-30 19:37:27 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:CommissionsRecords27502 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:CommissionsRecords27502 a sbvr:GeneralConcept,\n            sbvr:Extensionaldefinition,\n            sbvr:Term ;\n        sbvr:signifier "Commission\'s records" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-2(a)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "The Commission\'s records are by definition the records maintained by the Commission, which include copies of process, pleadings, or other papers served." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "Records maintained by the Commission, which include copies of process, pleadings, or other papers served." ;\n            cfr-sbvr:transformationSemscore 0.9214365593178433 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.9 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original definition with the structure provided by the template." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\ncfr-sbvr:transformationFinding "The transformation maintains the meaning of the original statement." ;\n\n            cfr-sbvr:classificationTemplatesId "T8" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal extensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:27Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to CommissionsRecords27502\n    OPTIONAL { cfr-sbvr:CommissionsRecords27502 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:27 - INFO - Upserted successfully.
# 2025-01-30 19:37:27 - INFO - Term 'Commission's records' done.
# 2025-01-30 19:37:27 - INFO - index=26
# 2025-01-30 19:37:28 - INFO - Vocabulary already exists
# 2025-01-30 19:37:28 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:37:28 - INFO - Found 0 similar signifier(s) for 'Order' on fibo:FIBO_Graph.
# 2025-01-30 19:37:28 - INFO - Found 0 similar signifier(s) for 'Order' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:28 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Order'.
# 2025-01-30 19:37:28 - INFO - Format Order to Order27505.
# 2025-01-30 19:37:28 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Order27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Order27505 a sbvr:GeneralConcept,\n            sbvr:IntensionalDefinition,\n            sbvr:Term ;\n        sbvr:signifier "Order" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-5(a)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-5(d)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-5(b)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "An Order is by definition a decision that is issued by the Commission disposing of the matter." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "A decision issued by the Commission disposing of the matter." ;\n            cfr-sbvr:transformationSemscore 0.8488492057110346 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.95 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 1.0 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original definition with the structure provided by the template." ;\ncfr-sbvr:transformationFinding "The use of \'by definition\' aligns with the template\'s requirement." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:28Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to Order27505\n    OPTIONAL { cfr-sbvr:Order27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:28 - INFO - Upserted successfully.
# 2025-01-30 19:37:28 - INFO - Term 'Order' done.
# 2025-01-30 19:37:28 - INFO - index=27
# 2025-01-30 19:37:28 - INFO - Vocabulary already exists
# 2025-01-30 19:37:28 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:37:28 - INFO - Found 0 similar signifier(s) for 'Period of time' on fibo:FIBO_Graph.
# 2025-01-30 19:37:29 - INFO - Found 0 similar signifier(s) for 'Period of time' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:29 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Period of time'.
# 2025-01-30 19:37:29 - INFO - Format Period of time to PeriodOfTime27505.
# 2025-01-30 19:37:29 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:PeriodOfTime27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:PeriodOfTime27505 a sbvr:GeneralConcept,\n            sbvr:DefinitionalRule,\n            sbvr:Term ;\n        sbvr:signifier "Period of time" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-5(a)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-5(b)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "The period of time of a notice is by definition the timeframe during which interested persons can submit facts or request a hearing." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "The timeframe specified in the notice during which interested persons can submit facts or request a hearing." ;\n            cfr-sbvr:transformationSemscore 0.9054555232625524 ;\n            cfr-sbvr:transformationSimilarityScore 0.9 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.95 ;\n            cfr-sbvr:transformationAccuracy 0.85 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n            cfr-sbvr:transformationFinding "The transformed sentence maintains the core meaning of the original statement but rephrases it to fit the template structure." ;\ncfr-sbvr:transformationFinding "The transformation accurately reflects the original statement, but the phrase \'specified in the notice\' is omitted, which slightly affects the transformation accuracy." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n            cfr-sbvr:classificationTemplatesId "T15" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Valid value definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:29Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to PeriodOfTime27505\n    OPTIONAL { cfr-sbvr:PeriodOfTime27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:29 - INFO - Upserted successfully.
# 2025-01-30 19:37:29 - INFO - Term 'Period of time' done.
# 2025-01-30 19:37:29 - INFO - index=28
# 2025-01-30 19:37:29 - INFO - Vocabulary already exists
# 2025-01-30 19:37:29 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:29 - INFO - Found 0 similar signifier(s) for 'Control' on fibo:FIBO_Graph.
# 2025-01-30 19:37:29 - INFO - Found 0 similar signifier(s) for 'Control' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:29 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Control'.
# 2025-01-30 19:37:29 - INFO - Format Control to Control27507.
# 2025-01-30 19:37:29 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Control27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Control27507 a sbvr:GeneralConcept,\n            sbvr:IntensionalDefinition,\n            sbvr:Term ;\n        sbvr:signifier "Control" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)" ;\nsbvr:referenceSupportsMeaning "§ 275.0-7(a)(3)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "Control is by definition the power that directly or indirectly directs the management or policies of a person, whether through ownership of securities, by contract, or otherwise." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "The power, directly or indirectly, to direct the management or policies of a person, whether through ownership of securities, by contract, or otherwise." ;\n            cfr-sbvr:transformationSemscore 0.8776129891885471 ;\n            cfr-sbvr:transformationSimilarityScore 0.95 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.9 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n            cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original definition with a slight rephrasing." ;\ncfr-sbvr:transformationFinding "The use of \'that\' in the transformed sentence maintains the meaning of the original definition." ;\ncfr-sbvr:transformationFinding "The transformation adheres to the T7 template structure, specifically using a qualifying clause." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n            cfr-sbvr:classificationTemplatesId "T7" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:29Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to Control27507\n    OPTIONAL { cfr-sbvr:Control27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:29 - INFO - Upserted successfully.
# 2025-01-30 19:37:29 - INFO - Term 'Control' done.
# 2025-01-30 19:37:29 - INFO - index=29
# 2025-01-30 19:37:30 - INFO - Vocabulary already exists
# 2025-01-30 19:37:30 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:37:30 - INFO - Found 0 similar signifier(s) for 'Evidence of service' on fibo:FIBO_Graph.
# 2025-01-30 19:37:30 - INFO - Found 0 similar signifier(s) for 'Evidence of service' on cfr-sbvr:CFR_SBVR.
# 2025-01-30 19:37:30 - INFO - Found 0 exact matche(s) and 0 close matche(s) for 'Evidence of service'.
# 2025-01-30 19:37:30 - INFO - Format Evidence of service to EvidenceOfService27502.
# 2025-01-30 19:37:30 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:EvidenceOfService27502 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:EvidenceOfService27502 a sbvr:GeneralConcept,\n            sbvr:Extensionaldefinition,\n            sbvr:Term ;\n        sbvr:signifier "Evidence of service" ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-2(a)(3)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "An evidence of service is by definition the certification by the Secretary that the Commission was served with process, pleadings, or other papers, or forwarded these documents to a named party." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n            cfr-sbvr:extractOriginalStatement "The certification by the Secretary that the Commission was served with process, pleadings, or other papers and forwarded these documents to a named party." ;\n            cfr-sbvr:transformationSemscore 0.8737902783125223 ;\n            cfr-sbvr:transformationSimilarityScore 0.85 ;\n            cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n            cfr-sbvr:transformationAccuracy 0.8 ;\n            cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n            cfr-sbvr:transformationFinding "The transformed sentence maintains the core meaning of the original definition but introduces a slight change in structure." ;\ncfr-sbvr:transformationFinding "The use of \'or\' in the transformed sentence slightly alters the meaning, as the original implies both actions (served and forwarded) are part of the certification." ;\ncfr-sbvr:transformationFinding "The transformation follows the template structure but could be more precise in reflecting the original statement\'s intent." ;\n\n            cfr-sbvr:classificationTemplatesId "T8" ;\n\n            cfr-sbvr:classificationType "Definitional rules" ;\n            cfr-sbvr:classificationSubtype "Formal extensional definitions" ;\n            cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n            cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n        \n        cfr-sbvr:createDate "2025-01-30T22:37:30Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to EvidenceOfService27502\n    OPTIONAL { cfr-sbvr:EvidenceOfService27502 ?p ?o . }\n}\n    '
# 2025-01-30 19:37:30 - INFO - Upserted successfully.
# 2025-01-30 19:37:30 - INFO - Term 'Evidence of service' done.

# %% [markdown]
# ### Rules and fact types

# %%
for index, element in enumerate(pred_operative_rules_fact_types):

    logger.info(f"{index=}")

    # from extraction
    doc_id = element.get('doc_id') # section

    statement_id = element.get('statement_id')
    
    statement = element.get('transformed')
    statement = statement if statement else "missing" # Change None to "missing"

    # SBVR ontology
    concept_type = "Rule" if element.get('source') == "Operative_Rules" else "Fact"
    
    statement_subject  = transform_to_rdf_subject(element.get('statement_title'))#generate_meaningful_rdf_subject(element.get('statement'))

    sources = element.get("statement_sources") # paragraph

    terms = element.get("terms")

    verb_symbols = element.get("verb_symbols")
    
    # from transformation
    metadata_cfr2sbvr = get_metadata_cfr2sbvr(element)

    # create vocabulary and namespace if not exists
    vocabulary = define_vocabulary_ns(kg_conn, doc_id, True)

    # create Fact model
    rule_fact_model = RuleAndFact(
        statement_id=statement_subject,
        statement=statement,
        concept_type=concept_type,
        terms=terms,
        verb_symbols=verb_symbols,
        vocabulary_namespace=vocabulary,
        sources=sources,
        doc_id=doc_id,
        metadata_cfr2sbvr=metadata_cfr2sbvr
    )

    # upsert
    query = upsert_rule_and_fact_query(rule_fact_model)
    logger.info(f"{query=}")
    status = upsert_to_kg(kg_conn, query)

    logger.info(f"{concept_type} '{statement_subject}' done.")
# Out:
# 2025-01-30 19:37:39 - INFO - index=0
# 2025-01-30 19:37:40 - INFO - Vocabulary already exists
# 2025-01-30 19:37:40 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:40 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:PresumptionOfControlInPartnership ?p ?o .\n}\nINSERT {\n    cfr-sbvr:PresumptionOfControlInPartnership a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:Dissolution ;\ncfr-sbvr:hasTerm cfr-sbvr:Partnership ;\ncfr-sbvr:hasTerm cfr-sbvr:Capital ;\ncfr-sbvr:hasTerm cfr-sbvr:RightToReceiveUponDissolution ;\ncfr-sbvr:hasTerm cfr-sbvr:Person ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:IsPresumedToControl ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Has ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:HasContributed ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(ii)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A person is by definition presumed to control a partnership that either has the right to receive upon dissolution or has contributed 25 percent or more of the capital of the partnership." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a partnership if the person has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the partnership." ;\n        cfr-sbvr:transformationSemscore 0.8896416187079522 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.9 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence maintains the original meaning but adds \'by definition\', which is consistent with the template." ;\ncfr-sbvr:transformationFinding "The structure of the transformed sentence follows the template T7 closely, using a qualifying clause." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\ncfr-sbvr:transformationFinding "The transformation accurately reflects the original statement, with minor rephrasing for template adherence." ;\n\n        cfr-sbvr:classificationTemplatesId "T7" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:40Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to PresumptionOfControlInPartnership\n    OPTIONAL { cfr-sbvr:PresumptionOfControlInPartnership ?p ?o . }\n}\n    '
# 2025-01-30 19:37:40 - INFO - Upserted successfully.
# 2025-01-30 19:37:40 - INFO - Fact 'PresumptionOfControlInPartnership' done.
# 2025-01-30 19:37:40 - INFO - index=1
# 2025-01-30 19:37:40 - INFO - Vocabulary already exists
# 2025-01-30 19:37:40 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:40 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:PresumptionOfControlInLlc ?p ?o .\n}\nINSERT {\n    cfr-sbvr:PresumptionOfControlInLlc a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:InterestsOfTheLlc ;\ncfr-sbvr:hasTerm cfr-sbvr:RightToVote ;\ncfr-sbvr:hasTerm cfr-sbvr:LimitedLiabilityCompanyllc ;\ncfr-sbvr:hasTerm cfr-sbvr:Capital ;\ncfr-sbvr:hasTerm cfr-sbvr:ElectedManager ;\ncfr-sbvr:hasTerm cfr-sbvr:RightToReceiveUponDissolution ;\ncfr-sbvr:hasTerm cfr-sbvr:Person ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:IsPresumedToControl ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Has ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:HasContributed ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Is ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(iii)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A person is by definition presumed to control a limited liability company (LLC) that either directly or indirectly has the right to vote 25 percent or more of a class of the interests of the LLC, has the right to receive upon dissolution, or has contributed 25 percent or more of the capital of the LLC, or is an elected manager of the LLC." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a limited liability company (LLC) if the person directly or indirectly has the right to vote 25 percent or more of a class of the interests of the LLC, has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the LLC, or is an elected manager of the LLC." ;\n        cfr-sbvr:transformationSemscore 0.9408193499937935 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.9 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence maintains the original meaning and structure closely, with minor adjustments to fit the template." ;\ncfr-sbvr:transformationFinding "The use of \'by definition\' in the transformed sentence aligns with the template\'s requirement." ;\ncfr-sbvr:transformationFinding "The transformed sentence is grammatically correct and syntactically accurate." ;\n\n        cfr-sbvr:classificationTemplatesId "T7" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:40Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to PresumptionOfControlInLlc\n    OPTIONAL { cfr-sbvr:PresumptionOfControlInLlc ?p ?o . }\n}\n    '
# 2025-01-30 19:37:41 - INFO - Upserted successfully.
# 2025-01-30 19:37:41 - INFO - Fact 'PresumptionOfControlInLlc' done.
# 2025-01-30 19:37:41 - INFO - index=2
# 2025-01-30 19:37:41 - INFO - Vocabulary already exists
# 2025-01-30 19:37:41 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:37:41 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:ManagingAgentDefinition ?p ?o .\n}\nINSERT {\n    cfr-sbvr:ManagingAgentDefinition a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:Trustee ;\ncfr-sbvr:hasTerm cfr-sbvr:ManagingAgent ;\ncfr-sbvr:hasTerm cfr-sbvr:Person ;\ncfr-sbvr:hasTerm cfr-sbvr:Association ;\ncfr-sbvr:hasTerm cfr-sbvr:Partnership ;\ncfr-sbvr:hasTerm cfr-sbvr:UnincorporatedOrganization ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:Means ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Directs ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Manages ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Participates ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-2(b)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A managing agent is by definition a person who directs or manages, or who participates in directing or managing, the affairs of any unincorporated organization or association other than a partnership." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Managing agent means any person, including a trustee, who directs or manages, or who participates in directing or managing, the affairs of any unincorporated organization or association other than a partnership." ;\n        cfr-sbvr:transformationSemscore 0.8708840103247764 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.95 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original statement with minor rephrasing." ;\ncfr-sbvr:transformationFinding "The use of \'by definition\' in the transformed sentence aligns with the template structure." ;\ncfr-sbvr:transformationFinding "The transformed sentence maintains the original meaning and context." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n        cfr-sbvr:classificationTemplatesId "T7" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:41Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to ManagingAgentDefinition\n    OPTIONAL { cfr-sbvr:ManagingAgentDefinition ?p ?o . }\n}\n    '
# 2025-01-30 19:37:41 - INFO - Upserted successfully.
# 2025-01-30 19:37:41 - INFO - Fact 'ManagingAgentDefinition' done.
# 2025-01-30 19:37:41 - INFO - index=3
# 2025-01-30 19:37:41 - INFO - Vocabulary already exists
# 2025-01-30 19:37:41 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:41 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:ControlOfTrustByPerson ?p ?o .\n}\nINSERT {\n    cfr-sbvr:ControlOfTrustByPerson a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:Trust ;\ncfr-sbvr:hasTerm cfr-sbvr:Trustee ;\ncfr-sbvr:hasTerm cfr-sbvr:ManagingAgent ;\ncfr-sbvr:hasTerm cfr-sbvr:Person ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:IsPresumedToControl ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Is ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(iv)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A person is by definition presumed to control a trust if the person is a trustee or managing agent of the trust." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a trust if the person is a trustee or managing agent of the trust." ;\n        cfr-sbvr:transformationSemscore 0.8330453068349398 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.9 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 1.0 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence maintains the original meaning and structure closely." ;\ncfr-sbvr:transformationFinding "The addition of \'by definition\' aligns with the template but slightly alters the emphasis." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n        cfr-sbvr:classificationTemplatesId "T7" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:41Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to ControlOfTrustByPerson\n    OPTIONAL { cfr-sbvr:ControlOfTrustByPerson ?p ?o . }\n}\n    '
# 2025-01-30 19:37:41 - INFO - Upserted successfully.
# 2025-01-30 19:37:41 - INFO - Fact 'ControlOfTrustByPerson' done.
# 2025-01-30 19:37:41 - INFO - index=4
# 2025-01-30 19:37:41 - INFO - Vocabulary already exists
# 2025-01-30 19:37:41 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:37:41 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:DefinitionOfApplication ?p ?o .\n}\nINSERT {\n    cfr-sbvr:DefinitionOfApplication a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:Act ;\ncfr-sbvr:hasTerm cfr-sbvr:Commission ;\ncfr-sbvr:hasTerm cfr-sbvr:OrderOfTheCommission ;\ncfr-sbvr:hasTerm cfr-sbvr:ApplicationForRegistration ;\ncfr-sbvr:hasTerm cfr-sbvr:InvestmentAdviser ;\ncfr-sbvr:hasTerm cfr-sbvr:Order ;\ncfr-sbvr:hasTerm cfr-sbvr:Application ;\ncfr-sbvr:hasTerm cfr-sbvr:Registration ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:Means ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-5(d)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "An application is by definition an application for an order of the Commission under the Act, other than an application for registration as an investment adviser." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "For purposes of this rule, an application means any application for an order of the Commission under the Act other than an application for registration as an investment adviser." ;\n        cfr-sbvr:transformationSemscore 0.8145172323260397 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.9 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Formal extensional definitions" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original statement\'s meaning." ;\ncfr-sbvr:transformationFinding "The transformation uses the template structure effectively, maintaining the original intent." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n        cfr-sbvr:classificationTemplatesId "T8" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:41Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to DefinitionOfApplication\n    OPTIONAL { cfr-sbvr:DefinitionOfApplication ?p ?o . }\n}\n    '
# 2025-01-30 19:37:41 - INFO - Upserted successfully.
# 2025-01-30 19:37:41 - INFO - Fact 'DefinitionOfApplication' done.
# 2025-01-30 19:37:41 - INFO - index=5
# 2025-01-30 19:37:42 - INFO - Vocabulary already exists
# 2025-01-30 19:37:42 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:42 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:AssetsUnderManagement ?p ?o .\n}\nINSERT {\n    cfr-sbvr:AssetsUnderManagement a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:FormAdv ;\ncfr-sbvr:hasTerm cfr-sbvr:AssetsUnderManagement ;\ncfr-sbvr:hasTerm cfr-sbvr:InvestmentAdviser ;\ncfr-sbvr:hasTerm cfr-sbvr:Commission ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:Has ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Defined ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Reported ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Deem ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-7(a)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "The assets under management of an investment adviser is by definition less than $25 million, or such higher amount as the Commission may by rule deem appropriate." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "An investment adviser has assets under management, as defined under Section 203A(a)(3) of the Act and reported on its annual updating amendment to Form ADV, of less than $25 million, or such higher amount as the Commission may by rule deem appropriate." ;\n        cfr-sbvr:transformationSemscore 0.8601091969152614 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.9 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Valid value definitions" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original statement\'s meaning." ;\ncfr-sbvr:transformationFinding "The transformation uses the template structure effectively, maintaining the original intent." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n        cfr-sbvr:classificationTemplatesId "T15" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:42Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to AssetsUnderManagement\n    OPTIONAL { cfr-sbvr:AssetsUnderManagement ?p ?o . }\n}\n    '
# 2025-01-30 19:37:42 - INFO - Upserted successfully.
# 2025-01-30 19:37:42 - INFO - Fact 'AssetsUnderManagement' done.
# 2025-01-30 19:37:42 - INFO - index=6
# 2025-01-30 19:37:42 - INFO - Vocabulary already exists
# 2025-01-30 19:37:42 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:42 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:InvestmentAdviserAssetRequirement ?p ?o .\n}\nINSERT {\n    cfr-sbvr:InvestmentAdviserAssetRequirement a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:FiscalYear ;\ncfr-sbvr:hasTerm cfr-sbvr:TotalAssets ;\ncfr-sbvr:hasTerm cfr-sbvr:InvestmentAdviser ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:DidNotHave ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-7(a)(2)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "The total assets of an investment adviser is by definition no more than $5 million on the last day of the most recent fiscal year." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "An investment adviser did not have total assets of $5 million or more on the last day of the most recent fiscal year." ;\n        cfr-sbvr:transformationSemscore 0.7924145574186922 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.9 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 1.0 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Valid value definitions" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original statement using the template T15." ;\ncfr-sbvr:transformationFinding "The inequality operator \'no more than\' is correctly used to reflect \'did not have ... or more\'." ;\ncfr-sbvr:transformationFinding "The transformation maintains the meaning of the original statement." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n        cfr-sbvr:classificationTemplatesId "T15" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:42Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to InvestmentAdviserAssetRequirement\n    OPTIONAL { cfr-sbvr:InvestmentAdviserAssetRequirement ?p ?o . }\n}\n    '
# 2025-01-30 19:37:42 - INFO - Upserted successfully.
# 2025-01-30 19:37:42 - INFO - Fact 'InvestmentAdviserAssetRequirement' done.
# 2025-01-30 19:37:42 - INFO - index=7
# 2025-01-30 19:37:42 - INFO - Vocabulary already exists
# 2025-01-30 19:37:42 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:42 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:ControlDefinition ?p ?o .\n}\nINSERT {\n    cfr-sbvr:ControlDefinition a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:Securities ;\ncfr-sbvr:hasTerm cfr-sbvr:Control ;\ncfr-sbvr:hasTerm cfr-sbvr:Power ;\ncfr-sbvr:hasTerm cfr-sbvr:Management ;\ncfr-sbvr:hasTerm cfr-sbvr:OwnershipOfSecurities ;\ncfr-sbvr:hasTerm cfr-sbvr:Contract ;\ncfr-sbvr:hasTerm cfr-sbvr:Policies ;\ncfr-sbvr:hasTerm cfr-sbvr:Person ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:Means ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:ToDirect ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "Control is by definition the power to direct the management or policies of a person, either directly or indirectly, whether through ownership of securities, by contract, or otherwise." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Control means the power, directly or indirectly, to direct the management or policies of a person, whether through ownership of securities, by contract, or otherwise." ;\n        cfr-sbvr:transformationSemscore 0.8156626410710727 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.9 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence maintains the original meaning and structure closely." ;\ncfr-sbvr:transformationFinding "The use of \'by definition\' in the transformed sentence aligns with the template structure." ;\ncfr-sbvr:transformationFinding "The phrase \'either directly or indirectly\' is correctly placed to reflect the original statement\'s intent." ;\ncfr-sbvr:transformationFinding "The transformed sentence is grammatically correct and syntactically accurate." ;\n\n        cfr-sbvr:classificationTemplatesId "T7" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:42Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to ControlDefinition\n    OPTIONAL { cfr-sbvr:ControlDefinition ?p ?o . }\n}\n    '
# 2025-01-30 19:37:42 - INFO - Upserted successfully.
# 2025-01-30 19:37:42 - INFO - Fact 'ControlDefinition' done.
# 2025-01-30 19:37:42 - INFO - index=8
# 2025-01-30 19:37:43 - INFO - Vocabulary already exists
# 2025-01-30 19:37:43 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:43 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:ControlPresumption ?p ?o .\n}\nINSERT {\n    cfr-sbvr:ControlPresumption a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:Corporation ;\ncfr-sbvr:hasTerm cfr-sbvr:VotingSecurities ;\ncfr-sbvr:hasTerm cfr-sbvr:RightToVote ;\ncfr-sbvr:hasTerm cfr-sbvr:Person ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:IsPresumedToControl ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Has ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(i)(A)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A person is by definition presumed to control a corporation that directly or indirectly has the right to vote 25 percent or more of a class of the corporation\'s voting securities." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a corporation if the person directly or indirectly has the right to vote 25 percent or more of a class of the corporation\'s voting securities." ;\n        cfr-sbvr:transformationSemscore 0.8732058642184732 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.85 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.9 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence maintains the core meaning of the original statement but adds \'by definition\' which slightly alters the context." ;\ncfr-sbvr:transformationFinding "The transformation uses the template structure but does not fully align with the original statement\'s conditional clause." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are mostly correct, but the insertion of \'by definition\' may not be necessary." ;\n\n        cfr-sbvr:classificationTemplatesId "T7" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:43Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to ControlPresumption\n    OPTIONAL { cfr-sbvr:ControlPresumption ?p ?o . }\n}\n    '
# 2025-01-30 19:37:46 - INFO - Upserted successfully.
# 2025-01-30 19:37:46 - INFO - Fact 'ControlPresumption' done.
# 2025-01-30 19:37:46 - INFO - index=9
# 2025-01-30 19:37:46 - INFO - Vocabulary already exists
# 2025-01-30 19:37:46 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:37:46 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:ServiceOfProcess ?p ?o .\n}\nINSERT {\n    cfr-sbvr:ServiceOfProcess a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:CommissionsRecords ;\ncfr-sbvr:hasTerm cfr-sbvr:NonresidentInvestmentAdviser ;\ncfr-sbvr:hasTerm cfr-sbvr:NonresidentGeneralPartner ;\ncfr-sbvr:hasTerm cfr-sbvr:NonresidentManagingAgent ;\ncfr-sbvr:hasTerm cfr-sbvr:Person ;\ncfr-sbvr:hasTerm cfr-sbvr:Commission ;\ncfr-sbvr:hasTerm cfr-sbvr:Papers ;\ncfr-sbvr:hasTerm cfr-sbvr:Process ;\ncfr-sbvr:hasTerm cfr-sbvr:NamedParty ;\ncfr-sbvr:hasTerm cfr-sbvr:Pleadings ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:Serve ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:ByFurnishing ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:With ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-2(a)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by definition exactly one copy of the process, pleadings, or papers for each named party." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by furnishing the Commission with one copy of the process, pleadings, or papers, for each named party, and one additional copy for the Commission\'s records." ;\n        cfr-sbvr:transformationSemscore 0.9178668892406184 ;\n        cfr-sbvr:transformationSimilarityScore 0.85 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.7 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.9 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Complex concept structure rules" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence captures the essence of the original statement but omits the requirement of an additional copy for the Commission\'s records." ;\ncfr-sbvr:transformationFinding "The transformation uses the template structure but does not fully align with the original statement\'s details." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are mostly correct, but the sentence structure could be clearer." ;\n\n        cfr-sbvr:classificationTemplatesId "T12" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:46Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to ServiceOfProcess\n    OPTIONAL { cfr-sbvr:ServiceOfProcess ?p ?o . }\n}\n    '
# 2025-01-30 19:37:46 - INFO - Upserted successfully.
# 2025-01-30 19:37:46 - INFO - Fact 'ServiceOfProcess' done.
# 2025-01-30 19:37:46 - INFO - index=10
# 2025-01-30 19:37:46 - INFO - Vocabulary already exists
# 2025-01-30 19:37:46 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:37:46 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:NonresidentDefinition ?p ?o .\n}\nINSERT {\n    cfr-sbvr:NonresidentDefinition a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:JurisdictionOfTheUnitedStates ;\ncfr-sbvr:hasTerm cfr-sbvr:Association ;\ncfr-sbvr:hasTerm cfr-sbvr:Partnership ;\ncfr-sbvr:hasTerm cfr-sbvr:Nonresident ;\ncfr-sbvr:hasTerm cfr-sbvr:Corporation ;\ncfr-sbvr:hasTerm cfr-sbvr:Individual ;\ncfr-sbvr:hasTerm cfr-sbvr:UnincorporatedOrganization ;\ncfr-sbvr:hasTerm cfr-sbvr:PlaceOfBusiness ;\ncfr-sbvr:hasTerm cfr-sbvr:PrincipalOffice ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:Means ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Resides ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:IsIncorporated ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Has ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-2(b)(2)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A non-resident is by definition an individual who resides in any place not subject to the jurisdiction of the United States, a corporation that is incorporated in or that has its principal office and place of business in any place not subject to the jurisdiction of the United States, or a partnership or other unincorporated organization or association that has its principal office and place of business in any place not subject to the jurisdiction of the United States." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Non-resident means an individual who resides in any place not subject to the jurisdiction of the United States; a corporation that is incorporated in or that has its principal office and place of business in any place not subject to the jurisdiction of the United States; and a partnership or other unincorporated organization or association that has its principal office and place of business in any place not subject to the jurisdiction of the United States." ;\n        cfr-sbvr:transformationSemscore 0.9196585994284018 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.95 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Formal extensional definitions" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original statement with minor rephrasing." ;\ncfr-sbvr:transformationFinding "The transformation maintains the meaning and structure of the original statement." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n        cfr-sbvr:classificationTemplatesId "T8" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:46Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to NonresidentDefinition\n    OPTIONAL { cfr-sbvr:NonresidentDefinition ?p ?o . }\n}\n    '
# 2025-01-30 19:37:46 - INFO - Upserted successfully.
# 2025-01-30 19:37:46 - INFO - Fact 'NonresidentDefinition' done.
# 2025-01-30 19:37:46 - INFO - index=11
# 2025-01-30 19:37:46 - INFO - Vocabulary already exists
# 2025-01-30 19:37:46 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:46 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:DefinitionOfSmallBusinessOrSmallOrganization ?p ?o .\n}\nINSERT {\n    cfr-sbvr:DefinitionOfSmallBusinessOrSmallOrganization a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:SmallOrganization ;\ncfr-sbvr:hasTerm cfr-sbvr:SmallBusiness ;\ncfr-sbvr:hasTerm cfr-sbvr:AssetsUnderManagement ;\ncfr-sbvr:hasTerm cfr-sbvr:InvestmentAdviser ;\ncfr-sbvr:hasTerm cfr-sbvr:Commission ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:ShallMean ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Has ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Deem ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-7(a)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A small business or small organization is by definition an investment adviser that has assets under management of less than $25 million, or such higher amount as the Commission may by rule deem appropriate." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "The term small business or small organization for purposes of the Investment Advisers Act of 1940 shall mean an investment adviser that has assets under management of less than $25 million, or such higher amount as the Commission may by rule deem appropriate." ;\n        cfr-sbvr:transformationSemscore 0.915926055795548 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.95 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 1.0 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original statement with a high degree of similarity." ;\ncfr-sbvr:transformationFinding "The transformation follows the template structure closely, maintaining the original meaning." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n        cfr-sbvr:classificationTemplatesId "T7" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:46Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to DefinitionOfSmallBusinessOrSmallOrganization\n    OPTIONAL { cfr-sbvr:DefinitionOfSmallBusinessOrSmallOrganization ?p ?o . }\n}\n    '
# 2025-01-30 19:37:47 - INFO - Upserted successfully.
# 2025-01-30 19:37:47 - INFO - Fact 'DefinitionOfSmallBusinessOrSmallOrganization' done.
# 2025-01-30 19:37:47 - INFO - index=12
# 2025-01-30 19:37:47 - INFO - Vocabulary already exists
# 2025-01-30 19:37:47 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:37:47 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:PrincipalOfficeAndPlaceOfBusinessDefinition ?p ?o .\n}\nINSERT {\n    cfr-sbvr:PrincipalOfficeAndPlaceOfBusinessDefinition a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:PlaceOfBusiness ;\ncfr-sbvr:hasTerm cfr-sbvr:PrincipalOffice ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:Has ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-2(b)(3)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A principal office and place of business is by definition the same as in § 275.203A-3(c) of this chapter." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Principal office and place of business has the same meaning as in § 275.203A-3(c) of this chapter." ;\n        cfr-sbvr:transformationSemscore 0.8835261359711172 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.9 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Formal intensional definitions" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence maintains the core meaning of the original statement, indicating a high similarity score." ;\ncfr-sbvr:transformationFinding "The transformation accurately reflects the original statement using the template structure, though the phrase \'by definition\' is added, which slightly alters the original phrasing." ;\ncfr-sbvr:transformationFinding "The transformed sentence is grammatically correct and syntactically accurate." ;\n\n        cfr-sbvr:classificationTemplatesId "T7" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:47Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to PrincipalOfficeAndPlaceOfBusinessDefinition\n    OPTIONAL { cfr-sbvr:PrincipalOfficeAndPlaceOfBusinessDefinition ?p ?o . }\n}\n    '
# 2025-01-30 19:37:47 - INFO - Upserted successfully.
# 2025-01-30 19:37:47 - INFO - Fact 'PrincipalOfficeAndPlaceOfBusinessDefinition' done.
# 2025-01-30 19:37:47 - INFO - index=13
# 2025-01-30 19:37:47 - INFO - Vocabulary already exists
# 2025-01-30 19:37:47 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:47 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:TotalAssetsDefinition ?p ?o .\n}\nINSERT {\n    cfr-sbvr:TotalAssetsDefinition a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:Subsidiaries ;\ncfr-sbvr:hasTerm cfr-sbvr:BalanceSheet ;\ncfr-sbvr:hasTerm cfr-sbvr:InvestmentAdviser ;\ncfr-sbvr:hasTerm cfr-sbvr:TotalAssets ;\ncfr-sbvr:hasTerm cfr-sbvr:Person ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:Means ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Shown ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(2)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A total assets is by definition the total assets as shown on the balance sheet of the investment adviser or other person described above under paragraph (a)(3) of this section, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Total assets means the total assets as shown on the balance sheet of the investment adviser or other person described above under paragraph (a)(3) of this section, or the balance sheet of the investment adviser or such other person with its subsidiaries consolidated, whichever is larger." ;\n        cfr-sbvr:transformationSemscore 0.9266452345971564 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.8 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.9 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Formal extensional definitions" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence closely follows the original statement but introduces an article \'A\' which is not necessary for the term \'total assets\'." ;\ncfr-sbvr:transformationFinding "The transformation maintains the meaning but slightly alters the structure, which affects the transformation accuracy." ;\ncfr-sbvr:transformationFinding "The grammar and syntax are mostly correct, but the use of \'A\' before \'total assets\' is awkward." ;\n\n        cfr-sbvr:classificationTemplatesId "T8" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:47Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to TotalAssetsDefinition\n    OPTIONAL { cfr-sbvr:TotalAssetsDefinition ?p ?o . }\n}\n    '
# 2025-01-30 19:37:47 - INFO - Upserted successfully.
# 2025-01-30 19:37:47 - INFO - Fact 'TotalAssetsDefinition' done.
# 2025-01-30 19:37:47 - INFO - index=14
# 2025-01-30 19:37:47 - INFO - Vocabulary already exists
# 2025-01-30 19:37:47 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:37:47 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:InvestmentAdviserControl ?p ?o .\n}\nINSERT {\n    cfr-sbvr:InvestmentAdviserControl a sbvr:Fact,\n            sbvr:DefinitionalRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:FiscalYear ;\ncfr-sbvr:hasTerm cfr-sbvr:NaturalPerson ;\ncfr-sbvr:hasTerm cfr-sbvr:AssetsUnderManagement ;\ncfr-sbvr:hasTerm cfr-sbvr:Control ;\ncfr-sbvr:hasTerm cfr-sbvr:InvestmentAdviser ;\ncfr-sbvr:hasTerm cfr-sbvr:Person ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:DoesNotControl ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:IsNotControlledBy ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:IsNotUnderCommonControlWith ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Has ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Had ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-7(a)(3)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "An investment adviser does not control, is not controlled by, and is not under common control with another investment adviser that has assets under management of at least $25 million, or any person (other than a natural person) that had total assets of at least $5 million on the last day of the most recent fiscal year." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "An investment adviser does not control, is not controlled by, and is not under common control with another investment adviser that has assets under management of $25 million or more, or any person (other than a natural person) that had total assets of $5 million or more on the last day of the most recent fiscal year." ;\n        cfr-sbvr:transformationSemscore 0.9722457918298332 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.9 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 1.0 ;\n        cfr-sbvr:classificationType "Definitional rules" ;\n        cfr-sbvr:classificationSubtype "Complex concept structure rules" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence accurately reflects the original statement with minor changes in phrasing." ;\ncfr-sbvr:transformationFinding "The use of \'at least\' in the transformed sentence is consistent with the original meaning of \'$25 million or more\' and \'$5 million or more\'." ;\ncfr-sbvr:transformationFinding "The transformation maintains the complex structure of the original statement." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct." ;\n\n        cfr-sbvr:classificationTemplatesId "T12" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:47Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to InvestmentAdviserControl\n    OPTIONAL { cfr-sbvr:InvestmentAdviserControl ?p ?o . }\n}\n    '
# 2025-01-30 19:37:47 - INFO - Upserted successfully.
# ...
# 2025-01-30 19:37:48 - INFO - Upserted successfully.
# 2025-01-30 19:37:48 - INFO - Rule 'EvidenceOfServiceCertification' done.
# 2025-01-30 19:37:48 - INFO - index=17
# 2025-01-30 19:37:48 - INFO - Vocabulary already exists
# 2025-01-30 19:37:48 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:37:48 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:OrderDisposition ?p ?o .\n}\nINSERT {\n    cfr-sbvr:OrderDisposition a sbvr:Rule,\n            sbvr:BehavioralBusinessRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:OrderDisposingOfTheMatter ;\ncfr-sbvr:hasTerm cfr-sbvr:PeriodOfTime ;\ncfr-sbvr:hasTerm cfr-sbvr:Order ;\ncfr-sbvr:hasTerm cfr-sbvr:Matter ;\ncfr-sbvr:hasTerm cfr-sbvr:Hearing ;\ncfr-sbvr:hasTerm cfr-sbvr:Commission ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:WillBeIssued ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Orders ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-5(b)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "An order disposing of the matter may be issued as of course following the expiration of the period of time referred to in paragraph (a) of this section only unless the Commission thereafter orders a hearing on the matter." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "An order disposing of the matter will be issued as of course following the expiration of the period of time referred to in paragraph (a) of this section, unless the Commission thereafter orders a hearing on the matter." ;\n        cfr-sbvr:transformationSemscore 0.9331721202713718 ;\n        cfr-sbvr:transformationSimilarityScore 0.9 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.8 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n        cfr-sbvr:classificationType "Activity rules" ;\n        cfr-sbvr:classificationSubtype "Activity obligation rules" ;\n        \n            cfr-sbvr:classificationTypeConfidence 1.0 ;\n            cfr-sbvr:classificationTypeExplanation "From true table" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence maintains the core meaning of the original statement but introduces \'may\' instead of \'will\', which slightly alters the obligation level." ;\ncfr-sbvr:transformationFinding "The transformation uses the template structure effectively, but the use of \'only unless\' is awkward and not standard English." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are mostly correct, but the phrase \'only unless\' is not typically used together." ;\n\n        cfr-sbvr:classificationTemplatesId "T49" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:48Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to OrderDisposition\n    OPTIONAL { cfr-sbvr:OrderDisposition ?p ?o . }\n}\n    '
# 2025-01-30 19:37:48 - INFO - Upserted successfully.
# 2025-01-30 19:37:48 - INFO - Rule 'OrderDisposition' done.
# 2025-01-30 19:37:48 - INFO - index=18
# 2025-01-30 19:37:49 - INFO - Vocabulary already exists
# 2025-01-30 19:37:49 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:37:49 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:HearingOrderByTheCommission ?p ?o .\n}\nINSERT {\n    cfr-sbvr:HearingOrderByTheCommission a sbvr:Rule,\n            sbvr:BehavioralBusinessRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:Motion ;\ncfr-sbvr:hasTerm cfr-sbvr:PublicInterest ;\ncfr-sbvr:hasTerm cfr-sbvr:Matter ;\ncfr-sbvr:hasTerm cfr-sbvr:InterestedPerson ;\ncfr-sbvr:hasTerm cfr-sbvr:ProtectionOfInvestors ;\ncfr-sbvr:hasTerm cfr-sbvr:Hearing ;\ncfr-sbvr:hasTerm cfr-sbvr:Commission ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:WillOrder ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Appears ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:IsNecessary ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:IsAppropriate ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-5(c)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "A hearing on the matter may be ordered by the Commission only if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion." ;\n        cfr-sbvr:transformationSemscore 0.9127932750480701 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.9 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n        cfr-sbvr:classificationType "Activity rules" ;\n        cfr-sbvr:classificationSubtype "Activity pre-condition rules" ;\n        \n            cfr-sbvr:classificationTypeConfidence 1.0 ;\n            cfr-sbvr:classificationTypeExplanation "From true table" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence maintains the original meaning and conditions for ordering a hearing." ;\ncfr-sbvr:transformationFinding "The structure of the transformed sentence aligns well with the T50 template, using the conditional clause appropriately." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct, with proper use of clauses and conjunctions." ;\n\n        cfr-sbvr:classificationTemplatesId "T50" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:49Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to HearingOrderByTheCommission\n    OPTIONAL { cfr-sbvr:HearingOrderByTheCommission ?p ?o . }\n}\n    '
# 2025-01-30 19:37:49 - INFO - Upserted successfully.
# 2025-01-30 19:37:49 - INFO - Rule 'HearingOrderByTheCommission' done.
# 2025-01-30 19:37:49 - INFO - index=19
# 2025-01-30 19:37:49 - INFO - Vocabulary already exists
# 2025-01-30 19:37:49 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:37:49 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:ForwardingCopiesToNamedParties ?p ?o .\n}\nINSERT {\n    cfr-sbvr:ForwardingCopiesToNamedParties a sbvr:Rule,\n            sbvr:BehavioralBusinessRule ;\n        \n        \n        sbvr:referenceSupportsMeaning "§ 275.0-2(a)(2)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "The Secretary of the Commission must forward a copy to each named party if the copy is by registered or certified mail at that party\'s last address filed with the Commission." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "The Secretary of the Commission (Secretary) will promptly forward a copy to each named party by registered or certified mail at that party\'s last address filed with the Commission." ;\n        cfr-sbvr:transformationSemscore 0.9090738208215441 ;\n        cfr-sbvr:transformationSimilarityScore 0.85 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.8 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n        cfr-sbvr:classificationType "None" ;\n        cfr-sbvr:classificationSubtype "None" ;\n        \n            cfr-sbvr:classificationTypeConfidence 0.0 ;\n            cfr-sbvr:classificationTypeExplanation "Not found" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence maintains the core meaning of the original statement but changes the modality from \'will\' to \'must\', which implies a stronger obligation." ;\ncfr-sbvr:transformationFinding "The conditional clause \'if the copy is by registered or certified mail\' is not present in the original statement, which affects the transformation accuracy." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct, but the introduction of the conditional clause may not accurately reflect the original intent." ;\n\n        cfr-sbvr:classificationTemplatesId "T56" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 0.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "Not found" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:49Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to ForwardingCopiesToNamedParties\n    OPTIONAL { cfr-sbvr:ForwardingCopiesToNamedParties ?p ?o . }\n}\n    '
# 2025-01-30 19:37:49 - INFO - Upserted successfully.
# 2025-01-30 19:37:49 - INFO - Rule 'ForwardingCopiesToNamedParties' done.
# 2025-01-30 19:37:49 - INFO - index=20
# 2025-01-30 19:37:49 - INFO - Vocabulary already exists
# 2025-01-30 19:37:49 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:37:49 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:SubmissionOfFactsAndHearingRequest ?p ?o .\n}\nINSERT {\n    cfr-sbvr:SubmissionOfFactsAndHearingRequest a sbvr:Rule,\n            sbvr:BehavioralBusinessRule ;\n        cfr-sbvr:hasTerm cfr-sbvr:NatureOfInterest ;\ncfr-sbvr:hasTerm cfr-sbvr:Facts ;\ncfr-sbvr:hasTerm cfr-sbvr:Reasons ;\ncfr-sbvr:hasTerm cfr-sbvr:OrderDisposingOfTheMatter ;\ncfr-sbvr:hasTerm cfr-sbvr:PeriodOfTime ;\ncfr-sbvr:hasTerm cfr-sbvr:InterestedPerson ;\ncfr-sbvr:hasTerm cfr-sbvr:Matter ;\ncfr-sbvr:hasTerm cfr-sbvr:Hearing ;\ncfr-sbvr:hasTerm cfr-sbvr:Commission ;\n\n        cfr-sbvr:hasVerbSymbol cfr-sbvr:MaySubmit ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:MayRequest ;\ncfr-sbvr:hasVerbSymbol cfr-sbvr:Stating ;\n\n        sbvr:referenceSupportsMeaning "§ 275.0-5(a)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "An interested person may submit to the Commission in writing any facts bearing upon the desirability of a hearing on the matter only if the period of time specified therein is met, and may request that a hearing be held, stating his reasons therefor and the nature of his interest in the matter." ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Any interested person may, within the period of time specified therein, submit to the Commission in writing any facts bearing upon the desirability of a hearing on the matter and may request that a hearing be held, stating his reasons therefor and the nature of his interest in the matter." ;\n        cfr-sbvr:transformationSemscore 0.9251312606540171 ;\n        cfr-sbvr:transformationSimilarityScore 0.95 ;\n        cfr-sbvr:transformationSimilarityScoreConfidence 0.9 ;\n        cfr-sbvr:transformationAccuracy 0.9 ;\n        cfr-sbvr:transformationGrammarSyntaxAccuracy 0.95 ;\n        cfr-sbvr:classificationType "Party rules" ;\n        cfr-sbvr:classificationSubtype "Party restriction rules" ;\n        \n            cfr-sbvr:classificationTypeConfidence 1.0 ;\n            cfr-sbvr:classificationTypeExplanation "From true table" ;\n        \n        cfr-sbvr:transformationFinding "The transformed sentence maintains the core meaning of the original statement." ;\ncfr-sbvr:transformationFinding "The transformation accurately reflects the structure of the template T53, incorporating the conditional clause appropriately." ;\ncfr-sbvr:transformationFinding "The grammar and syntax of the transformed sentence are correct, with proper use of conjunctions and clauses." ;\n\n        cfr-sbvr:classificationTemplatesId "T53" ;\n\n        cfr-sbvr:classificationSubtypeConfidence 1.0 ;\n        cfr-sbvr:classificationSubtypeExplanation "From true table" ;\n     \n        cfr-sbvr:createDate "2025-01-30T22:37:49Z"^^xsd:dateTime .\n}\nWHERE {\n    # Match all existing triples related to SubmissionOfFactsAndHearingRequest\n    OPTIONAL { cfr-sbvr:SubmissionOfFactsAndHearingRequest ?p ?o . }\n}\n    '
# 2025-01-30 19:37:49 - INFO - Upserted successfully.
# 2025-01-30 19:37:49 - INFO - Rule 'SubmissionOfFactsAndHearingRequest' done.

# %% [markdown]
# ### Verb symbols

# %%
for index, element in enumerate(pred_operative_rules_fact_types):

    logger.info(f"{index=}")

    # from extraction
    doc_id = element.get('doc_id') # section

    # There is no extracted / transformed statement for verb symbols
    # Storging the fact or rule statement as cfr-sbvr:transformedStatement
    statement = element.get('transformed')
    statement = statement if statement else "missing" # Change None to "missing"

    # SBVR ontology
    concept_type = "VerbConcept"
    
    sources = element.get("statement_sources") # paragraph

    verb_symbols = element.get("verb_symbols")
    
    # from transformation
    metadata_cfr2sbvr = get_metadata_cfr2sbvr(element)

    vocabulary = define_vocabulary_ns(kg_conn, doc_id, True)

    for verb_symbol in verb_symbols:
        # create Fact model
        designation_model = Designation(
            signifier=verb_symbol,
            statement=statement, # There is no extracted / transformed statement
            concept_type=concept_type,
            closeMatch=[],
            exactMatch=[],
            vocabulary_namespace=vocabulary,
            sources=sources,
            doc_id=doc_id,
            metadata_cfr2sbvr=metadata_cfr2sbvr
        )

        # upsert
        query = upsert_verb_symbol_query(designation_model)
        logger.info(f"{query=}")
        status = upsert_to_kg(kg_conn, query)
        logger.info(f"{concept_type} '{verb_symbol}' done.")
# Out:
# 2025-01-30 19:39:56 - INFO - index=0
# 2025-01-30 19:39:57 - INFO - Vocabulary already exists
# 2025-01-30 19:39:57 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:39:57 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:IsPresumedToControl27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:IsPresumedToControl27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "is presumed to control" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(ii)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a partnership if the person has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the partnership." ;\n        cfr-sbvr:transformedStatement "A person is by definition presumed to control a partnership that either has the right to receive upon dissolution or has contributed 25 percent or more of the capital of the partnership." ;\n        cfr-sbvr:createDate "2025-01-30T22:39:57Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to IsPresumedToControl27507\n    OPTIONAL { cfr-sbvr:IsPresumedToControl27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:39:57 - INFO - Upserted successfully.
# 2025-01-30 19:39:57 - INFO - VerbConcept 'is presumed to control' done.
# 2025-01-30 19:39:57 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Has27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Has27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "has" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(ii)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a partnership if the person has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the partnership." ;\n        cfr-sbvr:transformedStatement "A person is by definition presumed to control a partnership that either has the right to receive upon dissolution or has contributed 25 percent or more of the capital of the partnership." ;\n        cfr-sbvr:createDate "2025-01-30T22:39:57Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Has27507\n    OPTIONAL { cfr-sbvr:Has27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:39:57 - INFO - Upserted successfully.
# 2025-01-30 19:39:57 - INFO - VerbConcept 'has' done.
# 2025-01-30 19:39:57 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:HasContributed27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:HasContributed27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "has contributed" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(ii)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a partnership if the person has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the partnership." ;\n        cfr-sbvr:transformedStatement "A person is by definition presumed to control a partnership that either has the right to receive upon dissolution or has contributed 25 percent or more of the capital of the partnership." ;\n        cfr-sbvr:createDate "2025-01-30T22:39:57Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to HasContributed27507\n    OPTIONAL { cfr-sbvr:HasContributed27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:39:58 - INFO - Upserted successfully.
# 2025-01-30 19:39:58 - INFO - VerbConcept 'has contributed' done.
# 2025-01-30 19:39:58 - INFO - index=1
# 2025-01-30 19:39:58 - INFO - Vocabulary already exists
# 2025-01-30 19:39:58 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:39:58 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:IsPresumedToControl27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:IsPresumedToControl27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "is presumed to control" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(iii)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a limited liability company (LLC) if the person directly or indirectly has the right to vote 25 percent or more of a class of the interests of the LLC, has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the LLC, or is an elected manager of the LLC." ;\n        cfr-sbvr:transformedStatement "A person is by definition presumed to control a limited liability company (LLC) that either directly or indirectly has the right to vote 25 percent or more of a class of the interests of the LLC, has the right to receive upon dissolution, or has contributed 25 percent or more of the capital of the LLC, or is an elected manager of the LLC." ;\n        cfr-sbvr:createDate "2025-01-30T22:39:58Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to IsPresumedToControl27507\n    OPTIONAL { cfr-sbvr:IsPresumedToControl27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:39:58 - INFO - Upserted successfully.
# 2025-01-30 19:39:58 - INFO - VerbConcept 'is presumed to control' done.
# 2025-01-30 19:39:58 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Has27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Has27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "has" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(iii)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a limited liability company (LLC) if the person directly or indirectly has the right to vote 25 percent or more of a class of the interests of the LLC, has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the LLC, or is an elected manager of the LLC." ;\n        cfr-sbvr:transformedStatement "A person is by definition presumed to control a limited liability company (LLC) that either directly or indirectly has the right to vote 25 percent or more of a class of the interests of the LLC, has the right to receive upon dissolution, or has contributed 25 percent or more of the capital of the LLC, or is an elected manager of the LLC." ;\n        cfr-sbvr:createDate "2025-01-30T22:39:58Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Has27507\n    OPTIONAL { cfr-sbvr:Has27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:39:58 - INFO - Upserted successfully.
# 2025-01-30 19:39:58 - INFO - VerbConcept 'has' done.
# 2025-01-30 19:39:58 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:HasContributed27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:HasContributed27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "has contributed" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(iii)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a limited liability company (LLC) if the person directly or indirectly has the right to vote 25 percent or more of a class of the interests of the LLC, has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the LLC, or is an elected manager of the LLC." ;\n        cfr-sbvr:transformedStatement "A person is by definition presumed to control a limited liability company (LLC) that either directly or indirectly has the right to vote 25 percent or more of a class of the interests of the LLC, has the right to receive upon dissolution, or has contributed 25 percent or more of the capital of the LLC, or is an elected manager of the LLC." ;\n        cfr-sbvr:createDate "2025-01-30T22:39:58Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to HasContributed27507\n    OPTIONAL { cfr-sbvr:HasContributed27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:39:58 - INFO - Upserted successfully.
# 2025-01-30 19:39:58 - INFO - VerbConcept 'has contributed' done.
# 2025-01-30 19:39:58 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Is27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Is27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "is" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(iii)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a limited liability company (LLC) if the person directly or indirectly has the right to vote 25 percent or more of a class of the interests of the LLC, has the right to receive upon dissolution, or has contributed, 25 percent or more of the capital of the LLC, or is an elected manager of the LLC." ;\n        cfr-sbvr:transformedStatement "A person is by definition presumed to control a limited liability company (LLC) that either directly or indirectly has the right to vote 25 percent or more of a class of the interests of the LLC, has the right to receive upon dissolution, or has contributed 25 percent or more of the capital of the LLC, or is an elected manager of the LLC." ;\n        cfr-sbvr:createDate "2025-01-30T22:39:58Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Is27507\n    OPTIONAL { cfr-sbvr:Is27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:39:58 - INFO - Upserted successfully.
# 2025-01-30 19:39:58 - INFO - VerbConcept 'is' done.
# 2025-01-30 19:39:58 - INFO - index=2
# 2025-01-30 19:39:59 - INFO - Vocabulary already exists
# 2025-01-30 19:39:59 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:39:59 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Means27502 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Means27502 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "means" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-2(b)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Managing agent means any person, including a trustee, who directs or manages, or who participates in directing or managing, the affairs of any unincorporated organization or association other than a partnership." ;\n        cfr-sbvr:transformedStatement "A managing agent is by definition a person who directs or manages, or who participates in directing or managing, the affairs of any unincorporated organization or association other than a partnership." ;\n        cfr-sbvr:createDate "2025-01-30T22:39:59Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Means27502\n    OPTIONAL { cfr-sbvr:Means27502 ?p ?o . }\n}\n    '
# 2025-01-30 19:39:59 - INFO - Upserted successfully.
# 2025-01-30 19:39:59 - INFO - VerbConcept 'means' done.
# 2025-01-30 19:39:59 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Directs27502 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Directs27502 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "directs" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-2(b)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Managing agent means any person, including a trustee, who directs or manages, or who participates in directing or managing, the affairs of any unincorporated organization or association other than a partnership." ;\n        cfr-sbvr:transformedStatement "A managing agent is by definition a person who directs or manages, or who participates in directing or managing, the affairs of any unincorporated organization or association other than a partnership." ;\n        cfr-sbvr:createDate "2025-01-30T22:39:59Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Directs27502\n    OPTIONAL { cfr-sbvr:Directs27502 ?p ?o . }\n}\n    '
# 2025-01-30 19:39:59 - INFO - Upserted successfully.
# 2025-01-30 19:39:59 - INFO - VerbConcept 'directs' done.
# 2025-01-30 19:39:59 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Manages27502 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Manages27502 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "manages" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-2(b)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Managing agent means any person, including a trustee, who directs or manages, or who participates in directing or managing, the affairs of any unincorporated organization or association other than a partnership." ;\n        cfr-sbvr:transformedStatement "A managing agent is by definition a person who directs or manages, or who participates in directing or managing, the affairs of any unincorporated organization or association other than a partnership." ;\n        cfr-sbvr:createDate "2025-01-30T22:39:59Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Manages27502\n    OPTIONAL { cfr-sbvr:Manages27502 ?p ?o . }\n}\n    '
# 2025-01-30 19:39:59 - INFO - Upserted successfully.
# 2025-01-30 19:39:59 - INFO - VerbConcept 'manages' done.
# 2025-01-30 19:39:59 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Participates27502 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Participates27502 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "participates" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-2(b)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Managing agent means any person, including a trustee, who directs or manages, or who participates in directing or managing, the affairs of any unincorporated organization or association other than a partnership." ;\n        cfr-sbvr:transformedStatement "A managing agent is by definition a person who directs or manages, or who participates in directing or managing, the affairs of any unincorporated organization or association other than a partnership." ;\n        cfr-sbvr:createDate "2025-01-30T22:39:59Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Participates27502\n    OPTIONAL { cfr-sbvr:Participates27502 ?p ?o . }\n}\n    '
# 2025-01-30 19:39:59 - INFO - Upserted successfully.
# 2025-01-30 19:39:59 - INFO - VerbConcept 'participates' done.
# 2025-01-30 19:39:59 - INFO - index=3
# 2025-01-30 19:39:59 - INFO - Vocabulary already exists
# 2025-01-30 19:39:59 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:39:59 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:IsPresumedToControl27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:IsPresumedToControl27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "is presumed to control" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(iv)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a trust if the person is a trustee or managing agent of the trust." ;\n        cfr-sbvr:transformedStatement "A person is by definition presumed to control a trust if the person is a trustee or managing agent of the trust." ;\n        cfr-sbvr:createDate "2025-01-30T22:39:59Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to IsPresumedToControl27507\n    OPTIONAL { cfr-sbvr:IsPresumedToControl27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:00 - INFO - Upserted successfully.
# 2025-01-30 19:40:00 - INFO - VerbConcept 'is presumed to control' done.
# 2025-01-30 19:40:00 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Is27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Is27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "is" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(iv)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a trust if the person is a trustee or managing agent of the trust." ;\n        cfr-sbvr:transformedStatement "A person is by definition presumed to control a trust if the person is a trustee or managing agent of the trust." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:00Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Is27507\n    OPTIONAL { cfr-sbvr:Is27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:00 - INFO - Upserted successfully.
# 2025-01-30 19:40:00 - INFO - VerbConcept 'is' done.
# 2025-01-30 19:40:00 - INFO - index=4
# 2025-01-30 19:40:00 - INFO - Vocabulary already exists
# 2025-01-30 19:40:00 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:40:00 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Means27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Means27505 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "means" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-5(d)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "For purposes of this rule, an application means any application for an order of the Commission under the Act other than an application for registration as an investment adviser." ;\n        cfr-sbvr:transformedStatement "An application is by definition an application for an order of the Commission under the Act, other than an application for registration as an investment adviser." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:00Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Means27505\n    OPTIONAL { cfr-sbvr:Means27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:00 - INFO - Upserted successfully.
# 2025-01-30 19:40:00 - INFO - VerbConcept 'means' done.
# 2025-01-30 19:40:00 - INFO - index=5
# 2025-01-30 19:40:00 - INFO - Vocabulary already exists
# 2025-01-30 19:40:00 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:40:00 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Has27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Has27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "has" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(a)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "An investment adviser has assets under management, as defined under Section 203A(a)(3) of the Act and reported on its annual updating amendment to Form ADV, of less than $25 million, or such higher amount as the Commission may by rule deem appropriate." ;\n        cfr-sbvr:transformedStatement "The assets under management of an investment adviser is by definition less than $25 million, or such higher amount as the Commission may by rule deem appropriate." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:00Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Has27507\n    OPTIONAL { cfr-sbvr:Has27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:00 - INFO - Upserted successfully.
# 2025-01-30 19:40:00 - INFO - VerbConcept 'has' done.
# 2025-01-30 19:40:00 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Defined27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Defined27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "defined" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(a)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "An investment adviser has assets under management, as defined under Section 203A(a)(3) of the Act and reported on its annual updating amendment to Form ADV, of less than $25 million, or such higher amount as the Commission may by rule deem appropriate." ;\n        cfr-sbvr:transformedStatement "The assets under management of an investment adviser is by definition less than $25 million, or such higher amount as the Commission may by rule deem appropriate." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:00Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Defined27507\n    OPTIONAL { cfr-sbvr:Defined27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:01 - INFO - Upserted successfully.
# 2025-01-30 19:40:01 - INFO - VerbConcept 'defined' done.
# 2025-01-30 19:40:01 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Reported27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Reported27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "reported" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(a)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "An investment adviser has assets under management, as defined under Section 203A(a)(3) of the Act and reported on its annual updating amendment to Form ADV, of less than $25 million, or such higher amount as the Commission may by rule deem appropriate." ;\n        cfr-sbvr:transformedStatement "The assets under management of an investment adviser is by definition less than $25 million, or such higher amount as the Commission may by rule deem appropriate." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:01Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Reported27507\n    OPTIONAL { cfr-sbvr:Reported27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:01 - INFO - Upserted successfully.
# 2025-01-30 19:40:01 - INFO - VerbConcept 'reported' done.
# 2025-01-30 19:40:01 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Deem27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Deem27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "deem" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(a)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "An investment adviser has assets under management, as defined under Section 203A(a)(3) of the Act and reported on its annual updating amendment to Form ADV, of less than $25 million, or such higher amount as the Commission may by rule deem appropriate." ;\n        cfr-sbvr:transformedStatement "The assets under management of an investment adviser is by definition less than $25 million, or such higher amount as the Commission may by rule deem appropriate." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:01Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Deem27507\n    OPTIONAL { cfr-sbvr:Deem27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:01 - INFO - Upserted successfully.
# 2025-01-30 19:40:01 - INFO - VerbConcept 'deem' done.
# 2025-01-30 19:40:01 - INFO - index=6
# 2025-01-30 19:40:01 - INFO - Vocabulary already exists
# 2025-01-30 19:40:01 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:40:01 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:DidNotHave27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:DidNotHave27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "did not have" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(a)(2)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "An investment adviser did not have total assets of $5 million or more on the last day of the most recent fiscal year." ;\n        cfr-sbvr:transformedStatement "The total assets of an investment adviser is by definition no more than $5 million on the last day of the most recent fiscal year." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:01Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to DidNotHave27507\n    OPTIONAL { cfr-sbvr:DidNotHave27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:01 - INFO - Upserted successfully.
# 2025-01-30 19:40:01 - INFO - VerbConcept 'did not have' done.
# 2025-01-30 19:40:01 - INFO - index=7
# 2025-01-30 19:40:01 - INFO - Vocabulary already exists
# 2025-01-30 19:40:01 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:40:01 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Means27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Means27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "means" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Control means the power, directly or indirectly, to direct the management or policies of a person, whether through ownership of securities, by contract, or otherwise." ;\n        cfr-sbvr:transformedStatement "Control is by definition the power to direct the management or policies of a person, either directly or indirectly, whether through ownership of securities, by contract, or otherwise." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:01Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Means27507\n    OPTIONAL { cfr-sbvr:Means27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:02 - INFO - Upserted successfully.
# 2025-01-30 19:40:02 - INFO - VerbConcept 'means' done.
# 2025-01-30 19:40:02 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:ToDirect27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:ToDirect27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "to direct" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Control means the power, directly or indirectly, to direct the management or policies of a person, whether through ownership of securities, by contract, or otherwise." ;\n        cfr-sbvr:transformedStatement "Control is by definition the power to direct the management or policies of a person, either directly or indirectly, whether through ownership of securities, by contract, or otherwise." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:02Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to ToDirect27507\n    OPTIONAL { cfr-sbvr:ToDirect27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:02 - INFO - Upserted successfully.
# 2025-01-30 19:40:02 - INFO - VerbConcept 'to direct' done.
# 2025-01-30 19:40:02 - INFO - index=8
# 2025-01-30 19:40:02 - INFO - Vocabulary already exists
# 2025-01-30 19:40:02 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_7_NS
# 2025-01-30 19:40:02 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:IsPresumedToControl27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:IsPresumedToControl27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "is presumed to control" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(i)(A)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a corporation if the person directly or indirectly has the right to vote 25 percent or more of a class of the corporation\'s voting securities." ;\n        cfr-sbvr:transformedStatement "A person is by definition presumed to control a corporation that directly or indirectly has the right to vote 25 percent or more of a class of the corporation\'s voting securities." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:02Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to IsPresumedToControl27507\n    OPTIONAL { cfr-sbvr:IsPresumedToControl27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:02 - INFO - Upserted successfully.
# 2025-01-30 19:40:02 - INFO - VerbConcept 'is presumed to control' done.
# 2025-01-30 19:40:02 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Has27507 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Has27507 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "has" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-7(b)(1)(i)(A)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_7_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person is presumed to control a corporation if the person directly or indirectly has the right to vote 25 percent or more of a class of the corporation\'s voting securities." ;\n        cfr-sbvr:transformedStatement "A person is by definition presumed to control a corporation that directly or indirectly has the right to vote 25 percent or more of a class of the corporation\'s voting securities." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:02Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Has27507\n    OPTIONAL { cfr-sbvr:Has27507 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:02 - INFO - Upserted successfully.
# 2025-01-30 19:40:02 - INFO - VerbConcept 'has' done.
# 2025-01-30 19:40:02 - INFO - index=9
# 2025-01-30 19:40:02 - INFO - Vocabulary already exists
# 2025-01-30 19:40:02 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:40:02 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Serve27502 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Serve27502 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "serve" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-2(a)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by furnishing the Commission with one copy of the process, pleadings, or papers, for each named party, and one additional copy for the Commission\'s records." ;\n        cfr-sbvr:transformedStatement "A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by definition exactly one copy of the process, pleadings, or papers for each named party." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:02Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Serve27502\n    OPTIONAL { cfr-sbvr:Serve27502 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:02 - INFO - Upserted successfully.
# 2025-01-30 19:40:02 - INFO - VerbConcept 'serve' done.
# 2025-01-30 19:40:02 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:ByFurnishing27502 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:ByFurnishing27502 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "by furnishing" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-2(a)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by furnishing the Commission with one copy of the process, pleadings, or papers, for each named party, and one additional copy for the Commission\'s records." ;\n        cfr-sbvr:transformedStatement "A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by definition exactly one copy of the process, pleadings, or papers for each named party." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:02Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to ByFurnishing27502\n    OPTIONAL { cfr-sbvr:ByFurnishing27502 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:03 - INFO - Upserted successfully.
# 2025-01-30 19:40:03 - INFO - VerbConcept 'by furnishing' done.
# 2025-01-30 19:40:03 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:With27502 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:With27502 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "with" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-2(a)(1)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by furnishing the Commission with one copy of the process, pleadings, or papers, for each named party, and one additional copy for the Commission\'s records." ;\n        cfr-sbvr:transformedStatement "A person may serve a non-resident investment adviser, non-resident general partner, or non-resident managing agent by definition exactly one copy of the process, pleadings, or papers for each named party." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:03Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to With27502\n    OPTIONAL { cfr-sbvr:With27502 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:03 - INFO - Upserted successfully.
# 2025-01-30 19:40:03 - INFO - VerbConcept 'with' done.
# 2025-01-30 19:40:03 - INFO - index=10
# 2025-01-30 19:40:03 - INFO - Vocabulary already exists
# 2025-01-30 19:40:03 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:40:03 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Means27502 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Means27502 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "means" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-2(b)(2)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Non-resident means an individual who resides in any place not subject to the jurisdiction of the United States; a corporation that is incorporated in or that has its principal office and place of business in any place not subject to the jurisdiction of the United States; and a partnership or other unincorporated organization or association that has its principal office and place of business in any place not subject to the jurisdiction of the United States." ;\n        cfr-sbvr:transformedStatement "A non-resident is by definition an individual who resides in any place not subject to the jurisdiction of the United States, a corporation that is incorporated in or that has its principal office and place of business in any place not subject to the jurisdiction of the United States, or a partnership or other unincorporated organization or association that has its principal office and place of business in any place not subject to the jurisdiction of the United States." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:03Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Means27502\n    OPTIONAL { cfr-sbvr:Means27502 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:03 - INFO - Upserted successfully.
# 2025-01-30 19:40:03 - INFO - VerbConcept 'means' done.
# 2025-01-30 19:40:03 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Resides27502 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Resides27502 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "resides" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-2(b)(2)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_2_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Non-resident means an individual who resides in any place not subject to the jurisdiction of the United States; a corporation that is incorporated in or that has its principal office and place of business in any place not subject to the jurisdiction of the United States; and a partnership or other unincorporated organization or association that has its principal office and place of business in any place not subject to the jurisdiction of the United States." ;\n        cfr-sbvr:transformedStatement "A non-resident is by definition an individual who resides in any place not subject to the jurisdiction of the United States, a corporation that is incorporated in or that has its principal office and place of business in any place not subject to the jurisdiction of the United States, or a partnership or other unincorporated organization or association that has its principal office and place of business in any place not subject to the jurisdiction of the United States." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:03Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Resides27502\n    OPTIONAL { cfr-sbvr:Resides27502 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:03 - INFO - Upserted successfully.
# 2025-01-30 19:40:03 - INFO - VerbConcept 'resides' done.
# ...
# 2025-01-30 19:40:10 - INFO - Upserted successfully.
# 2025-01-30 19:40:10 - INFO - VerbConcept 'constitutes' done.
# 2025-01-30 19:40:10 - INFO - index=17
# 2025-01-30 19:40:11 - INFO - Vocabulary already exists
# 2025-01-30 19:40:11 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:40:11 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:WillBeIssued27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:WillBeIssued27505 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "will be issued" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-5(b)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "An order disposing of the matter will be issued as of course following the expiration of the period of time referred to in paragraph (a) of this section, unless the Commission thereafter orders a hearing on the matter." ;\n        cfr-sbvr:transformedStatement "An order disposing of the matter may be issued as of course following the expiration of the period of time referred to in paragraph (a) of this section only unless the Commission thereafter orders a hearing on the matter." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:11Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to WillBeIssued27505\n    OPTIONAL { cfr-sbvr:WillBeIssued27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:11 - INFO - Upserted successfully.
# 2025-01-30 19:40:11 - INFO - VerbConcept 'will be issued' done.
# 2025-01-30 19:40:11 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Orders27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Orders27505 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "orders" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-5(b)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "An order disposing of the matter will be issued as of course following the expiration of the period of time referred to in paragraph (a) of this section, unless the Commission thereafter orders a hearing on the matter." ;\n        cfr-sbvr:transformedStatement "An order disposing of the matter may be issued as of course following the expiration of the period of time referred to in paragraph (a) of this section only unless the Commission thereafter orders a hearing on the matter." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:11Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Orders27505\n    OPTIONAL { cfr-sbvr:Orders27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:11 - INFO - Upserted successfully.
# 2025-01-30 19:40:11 - INFO - VerbConcept 'orders' done.
# 2025-01-30 19:40:11 - INFO - index=18
# 2025-01-30 19:40:11 - INFO - Vocabulary already exists
# 2025-01-30 19:40:11 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:40:11 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:WillOrder27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:WillOrder27505 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "will order" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-5(c)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion." ;\n        cfr-sbvr:transformedStatement "A hearing on the matter may be ordered by the Commission only if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:11Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to WillOrder27505\n    OPTIONAL { cfr-sbvr:WillOrder27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:11 - INFO - Upserted successfully.
# 2025-01-30 19:40:11 - INFO - VerbConcept 'will order' done.
# 2025-01-30 19:40:11 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Appears27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Appears27505 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "appears" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-5(c)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion." ;\n        cfr-sbvr:transformedStatement "A hearing on the matter may be ordered by the Commission only if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:11Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Appears27505\n    OPTIONAL { cfr-sbvr:Appears27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:11 - INFO - Upserted successfully.
# 2025-01-30 19:40:11 - INFO - VerbConcept 'appears' done.
# 2025-01-30 19:40:11 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:IsNecessary27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:IsNecessary27505 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "is necessary" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-5(c)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion." ;\n        cfr-sbvr:transformedStatement "A hearing on the matter may be ordered by the Commission only if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:11Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to IsNecessary27505\n    OPTIONAL { cfr-sbvr:IsNecessary27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:12 - INFO - Upserted successfully.
# 2025-01-30 19:40:12 - INFO - VerbConcept 'is necessary' done.
# 2025-01-30 19:40:12 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:IsAppropriate27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:IsAppropriate27505 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "is appropriate" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-5(c)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "The Commission will order a hearing on the matter, if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion." ;\n        cfr-sbvr:transformedStatement "A hearing on the matter may be ordered by the Commission only if it appears that a hearing is necessary or appropriate in the public interest or for the protection of investors, upon the request of any interested person or upon its own motion." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:12Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to IsAppropriate27505\n    OPTIONAL { cfr-sbvr:IsAppropriate27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:12 - INFO - Upserted successfully.
# 2025-01-30 19:40:12 - INFO - VerbConcept 'is appropriate' done.
# 2025-01-30 19:40:12 - INFO - index=19
# 2025-01-30 19:40:12 - INFO - Vocabulary already exists
# 2025-01-30 19:40:12 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_2_NS
# 2025-01-30 19:40:12 - INFO - index=20
# 2025-01-30 19:40:12 - INFO - Vocabulary already exists
# 2025-01-30 19:40:12 - INFO - Vocabulary namespace: cfr-sbvr:CFR_SBVR_275_0_5_NS
# 2025-01-30 19:40:12 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:MaySubmit27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:MaySubmit27505 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "may submit" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-5(a)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Any interested person may, within the period of time specified therein, submit to the Commission in writing any facts bearing upon the desirability of a hearing on the matter and may request that a hearing be held, stating his reasons therefor and the nature of his interest in the matter." ;\n        cfr-sbvr:transformedStatement "An interested person may submit to the Commission in writing any facts bearing upon the desirability of a hearing on the matter only if the period of time specified therein is met, and may request that a hearing be held, stating his reasons therefor and the nature of his interest in the matter." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:12Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to MaySubmit27505\n    OPTIONAL { cfr-sbvr:MaySubmit27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:12 - INFO - Upserted successfully.
# 2025-01-30 19:40:12 - INFO - VerbConcept 'may submit' done.
# 2025-01-30 19:40:12 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:MayRequest27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:MayRequest27505 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "may request" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-5(a)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Any interested person may, within the period of time specified therein, submit to the Commission in writing any facts bearing upon the desirability of a hearing on the matter and may request that a hearing be held, stating his reasons therefor and the nature of his interest in the matter." ;\n        cfr-sbvr:transformedStatement "An interested person may submit to the Commission in writing any facts bearing upon the desirability of a hearing on the matter only if the period of time specified therein is met, and may request that a hearing be held, stating his reasons therefor and the nature of his interest in the matter." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:12Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to MayRequest27505\n    OPTIONAL { cfr-sbvr:MayRequest27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:12 - INFO - Upserted successfully.
# 2025-01-30 19:40:12 - INFO - VerbConcept 'may request' done.
# 2025-01-30 19:40:12 - INFO - query='\nPREFIX sbvr: <https://www.omg.org/spec/SBVR/20190601#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX cfr-sbvr: <http://cfr2sbvr.com/cfr#>\nPREFIX fro-cfr: <http://finregont.com/fro/cfr/Code_Federal_Regulations.ttl#>\n\nWITH cfr-sbvr:CFR_SBVR\nDELETE {\n    cfr-sbvr:Stating27505 ?p ?o .\n}\nINSERT {\n    cfr-sbvr:Stating27505 a sbvr:VerbSymbol,\n            sbvr:VerbConcept ;\n        sbvr:signifier "stating" ;\n        sbvr:referenceSupportsMeaning "§ 275.0-5(a)" ;\n\n        sbvr:isImplicitlyUnderstood "false"^^xsd:boolean ;\n        sbvr:statement "missing" ;\n        sbvr:designationIsInNamespace cfr-sbvr:CFR_SBVR_275_0_5_NS ;\n        \n        cfr-sbvr:extractOriginalStatement "Any interested person may, within the period of time specified therein, submit to the Commission in writing any facts bearing upon the desirability of a hearing on the matter and may request that a hearing be held, stating his reasons therefor and the nature of his interest in the matter." ;\n        cfr-sbvr:transformedStatement "An interested person may submit to the Commission in writing any facts bearing upon the desirability of a hearing on the matter only if the period of time specified therein is met, and may request that a hearing be held, stating his reasons therefor and the nature of his interest in the matter." ;\n        cfr-sbvr:createDate "2025-01-30T22:40:12Z"^^xsd:dateTime ;\n     .\n}\nWHERE {\n    # Match all existing triples related to Stating27505\n    OPTIONAL { cfr-sbvr:Stating27505 ?p ?o . }\n}\n    '
# 2025-01-30 19:40:13 - INFO - Upserted successfully.
# 2025-01-30 19:40:13 - INFO - VerbConcept 'stating' done.

# %% [markdown]
# ## Close database connection

# %%
kg_conn.close()
db_conn.close()
